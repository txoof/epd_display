# %% [markdown]
# url = "http://api.openweathermap.org/data/2.5/forecast?id=2747373&appid="

# %% [markdown]
# https://pypi.org/project/metno-locationforecast/#Usage

# %%
import requests
import logging
from urllib.parse import quote
import constants
from dictor import dictor

# %%
# %load_ext autoreload
# %autoreload 2

# %%
logging.root.setLevel('DEBUG')
logging.debug('foo')
# Out:
# DEBUG:root:foo

# %%
# wrap everything in trys
def get_coord(place=None):
    osm_endpoint = constants.osm_endpoint
    osm_query = constants.osm_query
    place_quote = quote(place)
    url = f'{osm_endpoint}{place_quote}{osm_query}'
    result = requests.get(url)
    lat = dictor(result.json()[0], 'lat')
    lon = dictor(result.json()[0], 'lon')
    display_name = dictor(result.json()[0], 'display_name')
    print(f'{display_name}: {float(lat):.2f}, {float(lon):.2f}')
    return(lat, lon)

# %%
coord = get_coord('Golden Colorado USA')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# DEBUG:urllib3.connectionpool:https://nominatim.openstreetmap.org:443 "GET /search/Golden%20Colorado%20USA?format=json&addressdetails=0&limit=0 HTTP/1.1" 200 None
# Golden, Jefferson County, Colorado, United States of America: 39.76, -105.22

# %%
def update_function(self):
    # build out the constants file with a reasonable (~80 value) set of data
    is_updated = False
    data = {}
    priority = 2**15
    
    failure = (is_updated, data, priority)
    
    try:
        forecast = requests.get(f"{constants.yr_endpoint}lat={self.config['lat']}&lon={self.config['lon']}")
    except RequestException as e:
        logging.warning(e)
        return failure
        
    
    if forecast.status_code == 200:
        data['updated_at'] = dictor(forecast.json(), 'properties.meta.updated_at')
        for index, each in enumerate(dictor(forecast.json(), 'properties.timeseries')):
            data[f'{index:03}_time'] = dictor(each, 'time')
            data[f'{index:03}_symbol_code'] = f'./images/png/{dictor(each, "data.next_1_hours.summary.symbol_code")}.png'
            data[f'{index:03}_precipitation_amount'] = dictor(each, "data.next_1_hours.details.precipitation_amount")
            for datum, value in dictor(each, 'data.instant.details').items():
                data[f'{index:03d}_{datum}'] = value
        priority = self.max_priority
        is_updated = True
    else:
        return failure
    
    return is_updated, data, priority

# %%
update_function(self)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.met.no:443
# DEBUG:urllib3.connectionpool:https://api.met.no:443 "GET /weatherapi/locationforecast/2.0/complete.json?lat=39.755543&lon=-105.2210997 HTTP/1.1" 200 3804
# (True,
#  {'updated_at': '2020-10-31T13:27:08Z',
#   '000_time': '2020-10-31T15:00:00Z',
#   '000_symbol_code': './images/png/clearsky_day.png',
#   '000_precipitation_amount': 0.0,
#   '000_air_pressure_at_sea_level': 1017.3,
#   '000_air_temperature': 6.6,
#   '000_cloud_area_fraction': 0.0,
#   '000_cloud_area_fraction_high': 0.0,
#   '000_cloud_area_fraction_low': 0.0,
#   '000_cloud_area_fraction_medium': 0.0,
#   '000_dew_point_temperature': -3.0,
#   '000_fog_area_fraction': 0.0,
#   '000_relative_humidity': 51.3,
#   '000_ultraviolet_index_clear_sky': 0.8,
#   '000_wind_from_direction': 278.4,
#   '000_wind_speed': 3.2,
#   '001_time': '2020-10-31T16:00:00Z',
#   '001_symbol_code': './images/png/clearsky_day.png',
#   '001_precipitation_amount': 0.0,
#   '001_air_pressure_at_sea_level': 1018.1,
#   '001_air_temperature': 12.7,
#   '001_cloud_area_fraction': 1.6,
#   '001_cloud_area_fraction_high': 0.0,
#   '001_cloud_area_fraction_low': 0.0,
#   '001_cloud_area_fraction_medium': 1.6,
#   '001_dew_point_temperature': -3.5,
#   '001_fog_area_fraction': 0.0,
#   '001_relative_humidity': 32.7,
#   '001_ultraviolet_index_clear_sky': 1.9,
#   '001_wind_from_direction': 227.4,
#   '001_wind_speed': 1.2,
#   '002_time': '2020-10-31T17:00:00Z',
#   '002_symbol_code': './images/png/clearsky_day.png',
#   '002_precipitation_amount': 0.0,
#   '002_air_pressure_at_sea_level': 1018.6,
#   '002_air_temperature': 13.7,
#   '002_cloud_area_fraction': 0.8,
#   '002_cloud_area_fraction_high': 0.0,
#   '002_cloud_area_fraction_low': 0.0,
#   '002_cloud_area_fraction_medium': 0.8,
#   '002_dew_point_temperature': -4.5,
#   '002_fog_area_fraction': 0.0,
#   '002_relative_humidity': 28.4,
#   '002_ultraviolet_index_clear_sky': 3.3,
#   '002_wind_from_direction': 84.8,
#   '002_wind_speed': 1.8,
#   '003_time': '2020-10-31T18:00:00Z',
#   '003_symbol_code': './images/png/clearsky_day.png',
#   '003_precipitation_amount': 0.0,
#   '003_air_pressure_at_sea_level': 1019.6,
#   '003_air_temperature': 14.7,
#   '003_cloud_area_fraction': 0.8,
#   '003_cloud_area_fraction_high': 0.0,
#   '003_cloud_area_fraction_low': 0.0,
#   '003_cloud_area_fraction_medium': 0.8,
#   '003_dew_point_temperature': -4.0,
#   '003_fog_area_fraction': 0.0,
#   '003_relative_humidity': 27.8,
#   '003_ultraviolet_index_clear_sky': 4.2,
#   '003_wind_from_direction': 31.5,
#   '003_wind_speed': 1.4,
#   '004_time': '2020-10-31T19:00:00Z',
#   '004_symbol_code': './images/png/clearsky_day.png',
#   '004_precipitation_amount': 0.0,
#   '004_air_pressure_at_sea_level': 1020.3,
#   '004_air_temperature': 15.5,
#   '004_cloud_area_fraction': 0.8,
#   '004_cloud_area_fraction_high': 0.0,
#   '004_cloud_area_fraction_low': 0.0,
#   '004_cloud_area_fraction_medium': 0.8,
#   '004_dew_point_temperature': -4.9,
#   '004_fog_area_fraction': 0.0,
#   '004_relative_humidity': 24.6,
#   '004_ultraviolet_index_clear_sky': 4.2,
#   '004_wind_from_direction': 345.9,
#   '004_wind_speed': 4.0,
#   '005_time': '2020-10-31T20:00:00Z',
#   '005_symbol_code': './images/png/clearsky_day.png',
#   '005_precipitation_amount': 0.0,
#   '005_air_pressure_at_sea_level': 1022.6,
#   '005_air_temperature': 12.2,
#   '005_cloud_area_fraction': 0.0,
#   '005_cloud_area_fraction_high': 0.0,
#   '005_cloud_area_fraction_low': 0.0,
#   '005_cloud_area_fraction_medium': 0.0,
#   '005_dew_point_temperature': -1.9,
#   '005_fog_area_fraction': 0.0,
#   '005_relative_humidity': 38.1,
#   '005_ultraviolet_index_clear_sky': 3.4,
#   '005_wind_from_direction': 28.9,
#   '005_wind_speed': 5.1,
#   '006_time': '2020-10-31T21:00:00Z',
#   '006_symbol_code': './images/png/clearsky_day.png',
#   '006_precipitation_amount': 0.0,
#   '006_air_pressure_at_sea_level': 1024.1,
#   '006_air_temperature': 11.3,
#   '006_cloud_area_fraction': 0.0,
#   '006_cloud_area_fraction_high': 0.0,
#   '006_cloud_area_fraction_low': 0.0,
#   '006_cloud_area_fraction_medium': 0.0,
#   '006_dew_point_temperature': -1.4,
#   '006_fog_area_fraction': 0.0,
#   '006_relative_humidity': 41.7,
#   '006_ultraviolet_index_clear_sky': 2.1,
#   '006_wind_from_direction': 41.2,
#   '006_wind_speed': 4.2,
#   '007_time': '2020-10-31T22:00:00Z',
#   '007_symbol_code': './images/png/clearsky_day.png',
#   '007_precipitation_amount': 0.0,
#   '007_air_pressure_at_sea_level': 1025.9,
#   '007_air_temperature': 9.9,
#   '007_cloud_area_fraction': 0.0,
#   '007_cloud_area_fraction_high': 0.0,
#   '007_cloud_area_fraction_low': 0.0,
#   '007_cloud_area_fraction_medium': 0.0,
#   '007_dew_point_temperature': -1.5,
#   '007_fog_area_fraction': 0.0,
#   '007_relative_humidity': 45.5,
#   '007_ultraviolet_index_clear_sky': 0.9,
#   '007_wind_from_direction': 53.3,
#   '007_wind_speed': 3.6,
#   '008_time': '2020-10-31T23:00:00Z',
#   '008_symbol_code': './images/png/clearsky_day.png',
#   '008_precipitation_amount': 0.0,
#   '008_air_pressure_at_sea_level': 1027.1,
#   '008_air_temperature': 8.6,
#   '008_cloud_area_fraction': 0.0,
#   '008_cloud_area_fraction_high': 0.0,
#   '008_cloud_area_fraction_low': 0.0,
#   '008_cloud_area_fraction_medium': 0.0,
#   '008_dew_point_temperature': -1.7,
#   '008_fog_area_fraction': 0.0,
#   '008_relative_humidity': 49.0,
#   '008_ultraviolet_index_clear_sky': 0.2,
#   '008_wind_from_direction': 75.4,
#   '008_wind_speed': 1.7,
#   '009_time': '2020-11-01T00:00:00Z',
#   '009_symbol_code': './images/png/clearsky_night.png',
#   '009_precipitation_amount': 0.0,
#   '009_air_pressure_at_sea_level': 1027.9,
#   '009_air_temperature': 5.1,
#   '009_cloud_area_fraction': 0.0,
#   '009_cloud_area_fraction_high': 0.0,
#   '009_cloud_area_fraction_low': 0.0,
#   '009_cloud_area_fraction_medium': 0.0,
#   '009_dew_point_temperature': -1.4,
#   '009_fog_area_fraction': 0.0,
#   '009_relative_humidity': 63.6,
#   '009_ultraviolet_index_clear_sky': 0.0,
#   '009_wind_from_direction': 215.1,
#   '009_wind_speed': 1.4,
#   '010_time': '2020-11-01T01:00:00Z',
#   '010_symbol_code': './images/png/clearsky_night.png',
#   '010_precipitation_amount': 0.0,
#   '010_air_pressure_at_sea_level': 1028.6,
#   '010_air_temperature': 4.3,
#   '010_cloud_area_fraction': 0.0,
#   '010_cloud_area_fraction_high': 0.0,
#   '010_cloud_area_fraction_low': 0.0,
#   '010_cloud_area_fraction_medium': 0.0,
#   '010_dew_point_temperature': -1.6,
#   '010_fog_area_fraction': 0.0,
#   '010_relative_humidity': 66.7,
#   '010_ultraviolet_index_clear_sky': 0.0,
#   '010_wind_from_direction': 241.4,
#   '010_wind_speed': 1.4,
#   '011_time': '2020-11-01T02:00:00Z',
#   '011_symbol_code': './images/png/clearsky_night.png',
#   '011_precipitation_amount': 0.0,
#   '011_air_pressure_at_sea_level': 1029.7,
#   '011_air_temperature': 3.5,
#   '011_cloud_area_fraction': 0.0,
#   '011_cloud_area_fraction_high': 0.0,
#   '011_cloud_area_fraction_low': 0.0,
#   '011_cloud_area_fraction_medium': 0.0,
#   '011_dew_point_temperature': -1.8,
#   '011_fog_area_fraction': 0.0,
#   '011_relative_humidity': 69.2,
#   '011_ultraviolet_index_clear_sky': 0.0,
#   '011_wind_from_direction': 232.1,
#   '011_wind_speed': 1.3,
#   '012_time': '2020-11-01T03:00:00Z',
#   '012_symbol_code': './images/png/clearsky_night.png',
#   '012_precipitation_amount': 0.0,
#   '012_air_pressure_at_sea_level': 1029.9,
#   '012_air_temperature': 2.8,
#   '012_cloud_area_fraction': 0.0,
#   '012_cloud_area_fraction_high': 0.0,
#   '012_cloud_area_fraction_low': 0.0,
#   '012_cloud_area_fraction_medium': 0.0,
#   '012_dew_point_temperature': -1.9,
#   '012_fog_area_fraction': 0.0,
#   '012_relative_humidity': 72.2,
#   '012_ultraviolet_index_clear_sky': 0.0,
#   '012_wind_from_direction': 235.6,
#   '012_wind_speed': 1.5,
#   '013_time': '2020-11-01T04:00:00Z',
#   '013_symbol_code': './images/png/clearsky_night.png',
#   '013_precipitation_amount': 0.0,
#   '013_air_pressure_at_sea_level': 1030.2,
#   '013_air_temperature': 2.0,
#   '013_cloud_area_fraction': 0.0,
#   '013_cloud_area_fraction_high': 0.0,
#   '013_cloud_area_fraction_low': 0.0,
#   '013_cloud_area_fraction_medium': 0.0,
#   '013_dew_point_temperature': -2.6,
#   '013_fog_area_fraction': 0.0,
#   '013_relative_humidity': 73.0,
#   '013_ultraviolet_index_clear_sky': 0.0,
#   '013_wind_from_direction': 233.9,
#   '013_wind_speed': 1.6,
#   '014_time': '2020-11-01T05:00:00Z',
#   '014_symbol_code': './images/png/clearsky_night.png',
#   '014_precipitation_amount': 0.0,
#   '014_air_pressure_at_sea_level': 1030.5,
#   '014_air_temperature': 0.9,
#   '014_cloud_area_fraction': 0.0,
#   '014_cloud_area_fraction_high': 0.0,
#   '014_cloud_area_fraction_low': 0.0,
#   '014_cloud_area_fraction_medium': 0.0,
#   '014_dew_point_temperature': -3.9,
#   '014_fog_area_fraction': 0.0,
#   '014_relative_humidity': 71.6,
#   '014_ultraviolet_index_clear_sky': 0.0,
#   '014_wind_from_direction': 253.5,
#   '014_wind_speed': 1.8,
#   '015_time': '2020-11-01T06:00:00Z',
#   '015_symbol_code': './images/png/clearsky_night.png',
#   '015_precipitation_amount': 0.0,
#   '015_air_pressure_at_sea_level': 1030.3,
#   '015_air_temperature': 0.3,
#   '015_cloud_area_fraction': 0.0,
#   '015_cloud_area_fraction_high': 0.0,
#   '015_cloud_area_fraction_low': 0.0,
#   '015_cloud_area_fraction_medium': 0.0,
#   '015_dew_point_temperature': -5.5,
#   '015_fog_area_fraction': 0.0,
#   '015_relative_humidity': 66.6,
#   '015_ultraviolet_index_clear_sky': 0.0,
#   '015_wind_from_direction': 262.1,
#   '015_wind_speed': 2.0,
#   '016_time': '2020-11-01T07:00:00Z',
#   '016_symbol_code': './images/png/clearsky_night.png',
#   '016_precipitation_amount': 0.0,
#   '016_air_pressure_at_sea_level': 1029.3,
#   '016_air_temperature': 0.2,
#   '016_cloud_area_fraction': 0.0,
#   '016_cloud_area_fraction_high': 0.0,
#   '016_cloud_area_fraction_low': 0.0,
#   '016_cloud_area_fraction_medium': 0.0,
#   '016_dew_point_temperature': -6.7,
#   '016_fog_area_fraction': 0.0,
#   '016_relative_humidity': 61.0,
#   '016_ultraviolet_index_clear_sky': 0.0,
#   '016_wind_from_direction': 256.6,
#   '016_wind_speed': 2.3,
#   '017_time': '2020-11-01T08:00:00Z',
#   '017_symbol_code': './images/png/clearsky_night.png',
#   '017_precipitation_amount': 0.0,
#   '017_air_pressure_at_sea_level': 1028.5,
#   '017_air_temperature': 0.0,
#   '017_cloud_area_fraction': 0.0,
#   '017_cloud_area_fraction_high': 0.0,
#   '017_cloud_area_fraction_low': 0.0,
#   '017_cloud_area_fraction_medium': 0.0,
#   '017_dew_point_temperature': -7.5,
#   '017_fog_area_fraction': 0.0,
#   '017_relative_humidity': 58.4,
#   '017_ultraviolet_index_clear_sky': 0.0,
#   '017_wind_from_direction': 265.4,
#   '017_wind_speed': 2.3,
#   '018_time': '2020-11-01T09:00:00Z',
#   '018_symbol_code': './images/png/clearsky_night.png',
#   '018_precipitation_amount': 0.0,
#   '018_air_pressure_at_sea_level': 1028.3,
#   '018_air_temperature': -0.1,
#   '018_cloud_area_fraction': 0.0,
#   '018_cloud_area_fraction_high': 0.0,
#   '018_cloud_area_fraction_low': 0.0,
#   '018_cloud_area_fraction_medium': 0.0,
#   '018_dew_point_temperature': -7.6,
#   '018_fog_area_fraction': 0.0,
#   '018_relative_humidity': 58.6,
#   '018_ultraviolet_index_clear_sky': 0.0,
#   '018_wind_from_direction': 273.4,
#   '018_wind_speed': 2.9,
#   '019_time': '2020-11-01T10:00:00Z',
#   '019_symbol_code': './images/png/clearsky_night.png',
#   '019_precipitation_amount': 0.0,
#   '019_air_pressure_at_sea_level': 1028.0,
#   '019_air_temperature': 0.6,
#   '019_cloud_area_fraction': 0.0,
#   '019_cloud_area_fraction_high': 0.0,
#   '019_cloud_area_fraction_low': 0.0,
#   '019_cloud_area_fraction_medium': 0.0,
#   '019_dew_point_temperature': -7.8,
#   '019_fog_area_fraction': 0.0,
#   '019_relative_humidity': 54.7,
#   '019_ultraviolet_index_clear_sky': 0.0,
#   '019_wind_from_direction': 278.7,
#   '019_wind_speed': 3.4,
#   '020_time': '2020-11-01T11:00:00Z',
#   '020_symbol_code': './images/png/clearsky_night.png',
#   '020_precipitation_amount': 0.0,
#   '020_air_pressure_at_sea_level': 1028.2,
#   '020_air_temperature': 0.4,
#   '020_cloud_area_fraction': 0.0,
#   '020_cloud_area_fraction_high': 0.0,
#   '020_cloud_area_fraction_low': 0.0,
#   '020_cloud_area_fraction_medium': 0.0,
#   '020_dew_point_temperature': -8.4,
#   '020_fog_area_fraction': 0.0,
#   '020_relative_humidity': 53.1,
#   '020_ultraviolet_index_clear_sky': 0.0,
#   '020_wind_from_direction': 274.2,
#   '020_wind_speed': 2.7,
#   '021_time': '2020-11-01T12:00:00Z',
#   '021_symbol_code': './images/png/clearsky_night.png',
#   '021_precipitation_amount': 0.0,
#   '021_air_pressure_at_sea_level': 1028.8,
#   '021_air_temperature': -0.2,
#   '021_cloud_area_fraction': 0.0,
#   '021_cloud_area_fraction_high': 0.0,
#   '021_cloud_area_fraction_low': 0.0,
#   '021_cloud_area_fraction_medium': 0.0,
#   '021_dew_point_temperature': -8.9,
#   '021_fog_area_fraction': 0.0,
#   '021_relative_humidity': 53.4,
#   '021_ultraviolet_index_clear_sky': 0.0,
#   '021_wind_from_direction': 264.5,
#   '021_wind_speed': 2.3,
#   '022_time': '2020-11-01T13:00:00Z',
#   '022_symbol_code': './images/png/clearsky_night.png',
#   '022_precipitation_amount': 0.0,
#   '022_air_pressure_at_sea_level': 1028.6,
#   '022_air_temperature': -0.1,
#   '022_cloud_area_fraction': 0.8,
#   '022_cloud_area_fraction_high': 0.0,
#   '022_cloud_area_fraction_low': 0.8,
#   '022_cloud_area_fraction_medium': 0.0,
#   '022_dew_point_temperature': -9.4,
#   '022_fog_area_fraction': 0.0,
#   '022_relative_humidity': 51.2,
#   '022_ultraviolet_index_clear_sky': 0.0,
#   '022_wind_from_direction': 263.4,
#   '022_wind_speed': 2.6,
#   '023_time': '2020-11-01T14:00:00Z',
#   '023_symbol_code': './images/png/clearsky_day.png',
#   '023_precipitation_amount': 0.0,
#   '023_air_pressure_at_sea_level': 1028.4,
#   '023_air_temperature': 1.0,
#   '023_cloud_area_fraction': 1.6,
#   '023_cloud_area_fraction_high': 0.0,
#   '023_cloud_area_fraction_low': 1.6,
#   '023_cloud_area_fraction_medium': 0.0,
#   '023_dew_point_temperature': -8.8,
#   '023_fog_area_fraction': 0.0,
#   '023_relative_humidity': 49.5,
#   '023_ultraviolet_index_clear_sky': 0.1,
#   '023_wind_from_direction': 259.6,
#   '023_wind_speed': 2.7,
#   '024_time': '2020-11-01T15:00:00Z',
#   '024_symbol_code': './images/png/clearsky_day.png',
#   '024_precipitation_amount': 0.0,
#   '024_air_pressure_at_sea_level': 1028.6,
#   '024_air_temperature': 5.9,
#   '024_cloud_area_fraction': 0.8,
#   '024_cloud_area_fraction_high': 0.0,
#   '024_cloud_area_fraction_low': 0.8,
#   '024_cloud_area_fraction_medium': 0.0,
#   '024_dew_point_temperature': -6.1,
#   '024_fog_area_fraction': 0.0,
#   '024_relative_humidity': 42.9,
#   '024_ultraviolet_index_clear_sky': 0.7,
#   '024_wind_from_direction': 239.3,
#   '024_wind_speed': 2.6,
#   '025_time': '2020-11-01T16:00:00Z',
#   '025_symbol_code': './images/png/clearsky_day.png',
#   '025_precipitation_amount': 0.0,
#   '025_air_pressure_at_sea_level': 1028.2,
#   '025_air_temperature': 10.5,
#   '025_cloud_area_fraction': 0.0,
#   '025_cloud_area_fraction_high': 0.0,
#   '025_cloud_area_fraction_low': 0.0,
#   '025_cloud_area_fraction_medium': 0.0,
#   '025_dew_point_temperature': -4.6,
#   '025_fog_area_fraction': 0.0,
#   '025_relative_humidity': 34.9,
#   '025_ultraviolet_index_clear_sky': 1.9,
#   '025_wind_from_direction': 156.3,
#   '025_wind_speed': 2.0,
#   '026_time': '2020-11-01T17:00:00Z',
#   '026_symbol_code': './images/png/clearsky_day.png',
#   '026_precipitation_amount': 0.0,
#   '026_air_pressure_at_sea_level': 1027.9,
#   '026_air_temperature': 12.4,
#   '026_cloud_area_fraction': 0.0,
#   '026_cloud_area_fraction_high': 0.0,
#   '026_cloud_area_fraction_low': 0.0,
#   '026_cloud_area_fraction_medium': 0.0,
#   '026_dew_point_temperature': -5.9,
#   '026_fog_area_fraction': 0.0,
#   '026_relative_humidity': 28.0,
#   '026_ultraviolet_index_clear_sky': 3.2,
#   '026_wind_from_direction': 138.1,
#   '026_wind_speed': 2.1,
#   '027_time': '2020-11-01T18:00:00Z',
#   '027_symbol_code': './images/png/clearsky_day.png',
#   '027_precipitation_amount': 0.0,
#   '027_air_pressure_at_sea_level': 1027.2,
#   '027_air_temperature': 14.2,
#   '027_cloud_area_fraction': 0.0,
#   '027_cloud_area_fraction_high': 0.0,
#   '027_cloud_area_fraction_low': 0.0,
#   '027_cloud_area_fraction_medium': 0.0,
#   '027_dew_point_temperature': -7.3,
#   '027_fog_area_fraction': 0.0,
#   '027_relative_humidity': 22.5,
#   '027_ultraviolet_index_clear_sky': 4.2,
#   '027_wind_from_direction': 130.3,
#   '027_wind_speed': 1.9,
#   '028_time': '2020-11-01T19:00:00Z',
#   '028_symbol_code': './images/png/clearsky_day.png',
#   '028_precipitation_amount': 0.0,
#   '028_air_pressure_at_sea_level': 1026.4,
#   '028_air_temperature': 15.1,
#   '028_cloud_area_fraction': 0.0,
#   '028_cloud_area_fraction_high': 0.0,
#   '028_cloud_area_fraction_low': 0.0,
#   '028_cloud_area_fraction_medium': 0.0,
#   '028_dew_point_temperature': -6.6,
#   '028_fog_area_fraction': 0.0,
#   '028_relative_humidity': 22.3,
#   '028_ultraviolet_index_clear_sky': 4.2,
#   '028_wind_from_direction': 113.1,
#   '028_wind_speed': 2.1,
#   '029_time': '2020-11-01T20:00:00Z',
#   '029_symbol_code': './images/png/clearsky_day.png',
#   '029_precipitation_amount': 0.0,
#   '029_air_pressure_at_sea_level': 1025.7,
#   '029_air_temperature': 15.5,
#   '029_cloud_area_fraction': 0.0,
#   '029_cloud_area_fraction_high': 0.0,
#   '029_cloud_area_fraction_low': 0.0,
#   '029_cloud_area_fraction_medium': 0.0,
#   '029_dew_point_temperature': -5.4,
#   '029_fog_area_fraction': 0.0,
#   '029_relative_humidity': 23.8,
#   '029_ultraviolet_index_clear_sky': 3.5,
#   '029_wind_from_direction': 110.5,
#   '029_wind_speed': 1.9,
#   '030_time': '2020-11-01T21:00:00Z',
#   '030_symbol_code': './images/png/clearsky_day.png',
#   '030_precipitation_amount': 0.0,
#   '030_air_pressure_at_sea_level': 1025.3,
#   '030_air_temperature': 15.7,
#   '030_cloud_area_fraction': 0.0,
#   '030_cloud_area_fraction_high': 0.0,
#   '030_cloud_area_fraction_low': 0.0,
#   '030_cloud_area_fraction_medium': 0.0,
#   '030_dew_point_temperature': -4.5,
#   '030_fog_area_fraction': 0.0,
#   '030_relative_humidity': 25.1,
#   '030_ultraviolet_index_clear_sky': 2.2,
#   '030_wind_from_direction': 112.7,
#   '030_wind_speed': 1.5,
#   '031_time': '2020-11-01T22:00:00Z',
#   '031_symbol_code': './images/png/clearsky_day.png',
#   '031_precipitation_amount': 0.0,
#   '031_air_pressure_at_sea_level': 1025.4,
#   '031_air_temperature': 15.4,
#   '031_cloud_area_fraction': 0.0,
#   '031_cloud_area_fraction_high': 0.0,
#   '031_cloud_area_fraction_low': 0.0,
#   '031_cloud_area_fraction_medium': 0.0,
#   '031_dew_point_temperature': -3.2,
#   '031_fog_area_fraction': 0.0,
#   '031_relative_humidity': 28.2,
#   '031_ultraviolet_index_clear_sky': 0.9,
#   '031_wind_from_direction': 113.5,
#   '031_wind_speed': 1.4,
#   '032_time': '2020-11-01T23:00:00Z',
#   '032_symbol_code': './images/png/clearsky_day.png',
#   '032_precipitation_amount': 0.0,
#   '032_air_pressure_at_sea_level': 1025.5,
#   '032_air_temperature': 13.4,
#   '032_cloud_area_fraction': 0.0,
#   '032_cloud_area_fraction_high': 0.0,
#   '032_cloud_area_fraction_low': 0.0,
#   '032_cloud_area_fraction_medium': 0.0,
#   '032_dew_point_temperature': 4.9,
#   '032_fog_area_fraction': 0.0,
#   '032_relative_humidity': 56.8,
#   '032_ultraviolet_index_clear_sky': 0.2,
#   '032_wind_from_direction': 109.7,
#   '032_wind_speed': 1.1,
#   '033_time': '2020-11-02T00:00:00Z',
#   '033_symbol_code': './images/png/clearsky_night.png',
#   '033_precipitation_amount': 0.0,
#   '033_air_pressure_at_sea_level': 1025.7,
#   '033_air_temperature': 11.8,
#   '033_cloud_area_fraction': 0.0,
#   '033_cloud_area_fraction_high': 0.0,
#   '033_cloud_area_fraction_low': 0.0,
#   '033_cloud_area_fraction_medium': 0.0,
#   '033_dew_point_temperature': -1.1,
#   '033_fog_area_fraction': 0.0,
#   '033_relative_humidity': 41.3,
#   '033_ultraviolet_index_clear_sky': 0.0,
#   '033_wind_from_direction': 262.6,
#   '033_wind_speed': 0.7,
#   '034_time': '2020-11-02T01:00:00Z',
#   '034_symbol_code': './images/png/clearsky_night.png',
#   '034_precipitation_amount': 0.0,
#   '034_air_pressure_at_sea_level': 1026.4,
#   '034_air_temperature': 11.2,
#   '034_cloud_area_fraction': 0.0,
#   '034_cloud_area_fraction_high': 0.0,
#   '034_cloud_area_fraction_low': 0.0,
#   '034_cloud_area_fraction_medium': 0.0,
#   '034_dew_point_temperature': -1.9,
#   '034_fog_area_fraction': 0.0,
#   '034_relative_humidity': 40.8,
#   '034_ultraviolet_index_clear_sky': 0.0,
#   '034_wind_from_direction': 263.8,
#   '034_wind_speed': 0.3,
#   '035_time': '2020-11-02T02:00:00Z',
#   '035_symbol_code': './images/png/clearsky_night.png',
#   '035_precipitation_amount': 0.0,
#   '035_air_pressure_at_sea_level': 1027.1,
#   '035_air_temperature': 6.4,
#   '035_cloud_area_fraction': 0.0,
#   '035_cloud_area_fraction_high': 0.0,
#   '035_cloud_area_fraction_low': 0.0,
#   '035_cloud_area_fraction_medium': 0.0,
#   '035_dew_point_temperature': -1.9,
#   '035_fog_area_fraction': 0.0,
#   '035_relative_humidity': 55.8,
#   '035_ultraviolet_index_clear_sky': 0.0,
#   '035_wind_from_direction': 263.3,
#   '035_wind_speed': 1.7,
#   '036_time': '2020-11-02T03:00:00Z',
#   '036_symbol_code': './images/png/clearsky_night.png',
#   '036_precipitation_amount': 0.0,
#   '036_air_pressure_at_sea_level': 1027.3,
#   '036_air_temperature': 5.3,
#   '036_cloud_area_fraction': 0.0,
#   '036_cloud_area_fraction_high': 0.0,
#   '036_cloud_area_fraction_low': 0.0,
#   '036_cloud_area_fraction_medium': 0.0,
#   '036_dew_point_temperature': -3.7,
#   '036_fog_area_fraction': 0.0,
#   '036_relative_humidity': 53.1,
#   '036_ultraviolet_index_clear_sky': 0.0,
#   '036_wind_from_direction': 264.3,
#   '036_wind_speed': 2.9,
#   '037_time': '2020-11-02T04:00:00Z',
#   '037_symbol_code': './images/png/clearsky_night.png',
#   '037_precipitation_amount': 0.0,
#   '037_air_pressure_at_sea_level': 1026.8,
#   '037_air_temperature': 4.9,
#   '037_cloud_area_fraction': 0.0,
#   '037_cloud_area_fraction_high': 0.0,
#   '037_cloud_area_fraction_low': 0.0,
#   '037_cloud_area_fraction_medium': 0.0,
#   '037_dew_point_temperature': -5.6,
#   '037_fog_area_fraction': 0.0,
#   '037_relative_humidity': 47.5,
#   '037_ultraviolet_index_clear_sky': 0.0,
#   '037_wind_from_direction': 265.2,
#   '037_wind_speed': 4.0,
#   '038_time': '2020-11-02T05:00:00Z',
#   '038_symbol_code': './images/png/clearsky_night.png',
#   '038_precipitation_amount': 0.0,
#   '038_air_pressure_at_sea_level': 1026.7,
#   '038_air_temperature': 5.8,
#   '038_cloud_area_fraction': 0.0,
#   '038_cloud_area_fraction_high': 0.0,
#   '038_cloud_area_fraction_low': 0.0,
#   '038_cloud_area_fraction_medium': 0.0,
#   '038_dew_point_temperature': -6.3,
#   '038_fog_area_fraction': 0.0,
#   '038_relative_humidity': 42.4,
#   '038_ultraviolet_index_clear_sky': 0.0,
#   '038_wind_from_direction': 268.9,
#   '038_wind_speed': 4.3,
#   '039_time': '2020-11-02T06:00:00Z',
#   '039_symbol_code': './images/png/clearsky_night.png',
#   '039_precipitation_amount': 0.0,
#   '039_air_pressure_at_sea_level': 1026.6,
#   '039_air_temperature': 6.1,
#   '039_cloud_area_fraction': 0.0,
#   '039_cloud_area_fraction_high': 0.0,
#   '039_cloud_area_fraction_low': 0.0,
#   '039_cloud_area_fraction_medium': 0.0,
#   '039_dew_point_temperature': -6.5,
#   '039_fog_area_fraction': 0.0,
#   '039_relative_humidity': 40.9,
#   '039_ultraviolet_index_clear_sky': 0.0,
#   '039_wind_from_direction': 267.3,
#   '039_wind_speed': 4.1,
#   '040_time': '2020-11-02T07:00:00Z',
#   '040_symbol_code': './images/png/clearsky_night.png',
#   '040_precipitation_amount': 0.0,
#   '040_air_pressure_at_sea_level': 1026.3,
#   '040_air_temperature': 6.5,
#   '040_cloud_area_fraction': 0.0,
#   '040_cloud_area_fraction_high': 0.0,
#   '040_cloud_area_fraction_low': 0.0,
#   '040_cloud_area_fraction_medium': 0.0,
#   '040_dew_point_temperature': -7.0,
#   '040_fog_area_fraction': 0.0,
#   '040_relative_humidity': 38.3,
#   '040_ultraviolet_index_clear_sky': 0.0,
#   '040_wind_from_direction': 265.5,
#   '040_wind_speed': 4.3,
#   '041_time': '2020-11-02T08:00:00Z',
#   '041_symbol_code': './images/png/clearsky_night.png',
#   '041_precipitation_amount': 0.0,
#   '041_air_pressure_at_sea_level': 1026.1,
#   '041_air_temperature': 6.8,
#   '041_cloud_area_fraction': 0.0,
#   '041_cloud_area_fraction_high': 0.0,
#   '041_cloud_area_fraction_low': 0.0,
#   '041_cloud_area_fraction_medium': 0.0,
#   '041_dew_point_temperature': -7.4,
#   '041_fog_area_fraction': 0.0,
#   '041_relative_humidity': 36.2,
#   '041_ultraviolet_index_clear_sky': 0.0,
#   '041_wind_from_direction': 265.1,
#   '041_wind_speed': 4.5,
#   '042_time': '2020-11-02T09:00:00Z',
#   '042_symbol_code': './images/png/clearsky_night.png',
#   '042_precipitation_amount': 0.0,
#   '042_air_pressure_at_sea_level': 1026.0,
#   '042_air_temperature': 7.1,
#   '042_cloud_area_fraction': 0.0,
#   '042_cloud_area_fraction_high': 0.0,
#   '042_cloud_area_fraction_low': 0.0,
#   '042_cloud_area_fraction_medium': 0.0,
#   '042_dew_point_temperature': -7.8,
#   '042_fog_area_fraction': 0.0,
#   '042_relative_humidity': 34.8,
#   '042_ultraviolet_index_clear_sky': 0.0,
#   '042_wind_from_direction': 266.3,
#   '042_wind_speed': 4.6,
#   '043_time': '2020-11-02T10:00:00Z',
#   '043_symbol_code': './images/png/clearsky_night.png',
#   '043_precipitation_amount': 0.0,
#   '043_air_pressure_at_sea_level': 1025.6,
#   '043_air_temperature': 6.9,
#   '043_cloud_area_fraction': 0.0,
#   '043_cloud_area_fraction_high': 0.0,
#   '043_cloud_area_fraction_low': 0.0,
#   '043_cloud_area_fraction_medium': 0.0,
#   '043_dew_point_temperature': -7.9,
#   '043_fog_area_fraction': 0.0,
#   '043_relative_humidity': 35.0,
#   '043_ultraviolet_index_clear_sky': 0.0,
#   '043_wind_from_direction': 269.2,
#   '043_wind_speed': 4.6,
#   '044_time': '2020-11-02T11:00:00Z',
#   '044_symbol_code': './images/png/clearsky_night.png',
#   '044_precipitation_amount': 0.0,
#   '044_air_pressure_at_sea_level': 1025.3,
#   '044_air_temperature': 6.5,
#   '044_cloud_area_fraction': 0.0,
#   '044_cloud_area_fraction_high': 0.0,
#   '044_cloud_area_fraction_low': 0.0,
#   '044_cloud_area_fraction_medium': 0.0,
#   '044_dew_point_temperature': -8.0,
#   '044_fog_area_fraction': 0.0,
#   '044_relative_humidity': 35.4,
#   '044_ultraviolet_index_clear_sky': 0.0,
#   '044_wind_from_direction': 270.6,
#   '044_wind_speed': 4.6,
#   '045_time': '2020-11-02T12:00:00Z',
#   '045_symbol_code': './images/png/clearsky_night.png',
#   '045_precipitation_amount': 0.0,
#   '045_air_pressure_at_sea_level': 1025.4,
#   '045_air_temperature': 6.4,
#   '045_cloud_area_fraction': 0.0,
#   '045_cloud_area_fraction_high': 0.0,
#   '045_cloud_area_fraction_low': 0.0,
#   '045_cloud_area_fraction_medium': 0.0,
#   '045_dew_point_temperature': -8.1,
#   '045_fog_area_fraction': 0.0,
#   '045_relative_humidity': 35.6,
#   '045_ultraviolet_index_clear_sky': 0.0,
#   '045_wind_from_direction': 270.0,
#   '045_wind_speed': 4.6,
#   '046_time': '2020-11-02T13:00:00Z',
#   '046_symbol_code': './images/png/clearsky_night.png',
#   '046_precipitation_amount': 0.0,
#   '046_air_pressure_at_sea_level': 1025.3,
#   '046_air_temperature': 6.1,
#   '046_cloud_area_fraction': 0.0,
#   '046_cloud_area_fraction_high': 0.0,
#   '046_cloud_area_fraction_low': 0.0,
#   '046_cloud_area_fraction_medium': 0.0,
#   '046_dew_point_temperature': -8.0,
#   '046_fog_area_fraction': 0.0,
#   '046_relative_humidity': 36.6,
#   '046_ultraviolet_index_clear_sky': 0.0,
#   '046_wind_from_direction': 269.4,
#   '046_wind_speed': 4.4,
#   '047_time': '2020-11-02T14:00:00Z',
#   '047_symbol_code': './images/png/clearsky_day.png',
#   '047_precipitation_amount': 0.0,
#   '047_air_pressure_at_sea_level': 1025.3,
#   '047_air_temperature': 6.4,
#   '047_cloud_area_fraction': 0.0,
#   '047_cloud_area_fraction_high': 0.0,
#   '047_cloud_area_fraction_low': 0.0,
#   '047_cloud_area_fraction_medium': 0.0,
#   '047_dew_point_temperature': -7.3,
#   '047_fog_area_fraction': 0.0,
#   '047_relative_humidity': 37.7,
#   '047_ultraviolet_index_clear_sky': 0.1,
#   '047_wind_from_direction': 270.4,
#   '047_wind_speed': 4.3,
#   '048_time': '2020-11-02T15:00:00Z',
#   '048_symbol_code': './images/png/clearsky_day.png',
#   '048_precipitation_amount': 0.0,
#   '048_air_pressure_at_sea_level': 1025.7,
#   '048_air_temperature': 9.8,
#   '048_cloud_area_fraction': 0.0,
#   '048_cloud_area_fraction_high': 0.0,
#   '048_cloud_area_fraction_low': 0.0,
#   '048_cloud_area_fraction_medium': 0.0,
#   '048_dew_point_temperature': -4.5,
#   '048_fog_area_fraction': 0.0,
#   '048_relative_humidity': 36.7,
#   '048_ultraviolet_index_clear_sky': 0.7,
#   '048_wind_from_direction': 273.1,
#   '048_wind_speed': 3.8,
#   '049_time': '2020-11-02T16:00:00Z',
#   '049_symbol_code': './images/png/clearsky_day.png',
#   '049_precipitation_amount': 0.0,
#   '049_air_pressure_at_sea_level': 1026.0,
#   '049_air_temperature': 14.3,
#   '049_cloud_area_fraction': 0.0,
#   '049_cloud_area_fraction_high': 0.0,
#   '049_cloud_area_fraction_low': 0.0,
#   '049_cloud_area_fraction_medium': 0.0,
#   '049_dew_point_temperature': -1.8,
#   '049_fog_area_fraction': 0.0,
#   '049_relative_humidity': 33.3,
#   '049_ultraviolet_index_clear_sky': 1.7,
#   '049_wind_from_direction': 285.7,
#   '049_wind_speed': 2.0,
#   '050_time': '2020-11-02T17:00:00Z',
#   '050_symbol_code': './images/png/clearsky_day.png',
#   '050_precipitation_amount': 0.0,
#   '050_air_pressure_at_sea_level': 1025.4,
#   '050_air_temperature': 16.6,
#   '050_cloud_area_fraction': 0.0,
#   '050_cloud_area_fraction_high': 0.0,
#   '050_cloud_area_fraction_low': 0.0,
#   '050_cloud_area_fraction_medium': 0.0,
#   '050_dew_point_temperature': -1.1,
#   '050_fog_area_fraction': 0.0,
#   '050_relative_humidity': 30.3,
#   '050_ultraviolet_index_clear_sky': 3.0,
#   '050_wind_from_direction': 37.7,
#   '050_wind_speed': 0.8,
#   '051_time': '2020-11-02T18:00:00Z',
#   '051_symbol_code': './images/png/clearsky_day.png',
#   '051_precipitation_amount': 0.0,
#   '051_air_pressure_at_sea_level': 1024.4,
#   '051_air_temperature': 17.5,
#   '051_cloud_area_fraction': 0.0,
#   '051_cloud_area_fraction_high': 0.0,
#   '051_cloud_area_fraction_low': 0.0,
#   '051_cloud_area_fraction_medium': 0.0,
#   '051_dew_point_temperature': 0.3,
#   '051_fog_area_fraction': 0.0,
#   '051_relative_humidity': 31.5,
#   '051_ultraviolet_index_clear_sky': 3.8,
#   '051_wind_from_direction': 67.4,
#   '051_wind_speed': 1.6,
#   '052_time': '2020-11-02T19:00:00Z',
#   '052_symbol_code': './images/png/clearsky_day.png',
#   '052_precipitation_amount': 0.0,
#   '052_air_pressure_at_sea_level': 1023.5,
#   '052_air_temperature': 17.8,
#   '052_cloud_area_fraction': 0.0,
#   '052_cloud_area_fraction_high': 0.0,
#   '052_cloud_area_fraction_low': 0.0,
#   '052_cloud_area_fraction_medium': 0.0,
#   '052_dew_point_temperature': 1.6,
#   '052_fog_area_fraction': 0.0,
#   '052_relative_humidity': 34.0,
#   '052_ultraviolet_index_clear_sky': 3.9,
#   '052_wind_from_direction': 84.8,
#   '052_wind_speed': 1.9,
#   '053_time': '2020-11-02T20:00:00Z',
#   '053_symbol_code': './images/png/clearsky_day.png',
#   '053_precipitation_amount': 0.0,
#   '053_air_pressure_at_sea_level': 1022.4,
#   '053_air_temperature': 18.2,
#   '053_cloud_area_fraction': 0.0,
#   '053_cloud_area_fraction_high': 0.0,
#   '053_cloud_area_fraction_low': 0.0,
#   '053_cloud_area_fraction_medium': 0.0,
#   '053_dew_point_temperature': 0.8,
#   '053_fog_area_fraction': 0.0,
#   '053_relative_humidity': 31.3,
#   '053_ultraviolet_index_clear_sky': 3.2,
#   '053_wind_from_direction': 90.9,
#   '053_wind_speed': 1.7,
#   '054_time': '2020-11-02T21:00:00Z',
#   '054_symbol_code': './images/png/clearsky_day.png',
#   '054_precipitation_amount': 0.0,
#   '054_air_pressure_at_sea_level': 1021.6,
#   '054_air_temperature': 18.4,
#   '054_cloud_area_fraction': 0.0,
#   '054_cloud_area_fraction_high': 0.0,
#   '054_cloud_area_fraction_low': 0.0,
#   '054_cloud_area_fraction_medium': 0.0,
#   '054_dew_point_temperature': -0.5,
#   '054_fog_area_fraction': 0.0,
#   '054_relative_humidity': 28.2,
#   '054_ultraviolet_index_clear_sky': 2.0,
#   '054_wind_from_direction': 96.1,
#   '054_wind_speed': 1.5,
#   '055_time': '2020-11-02T22:00:00Z',
#   '055_symbol_code': './images/png/clearsky_day.png',
#   '055_precipitation_amount': 0.0,
#   '055_air_pressure_at_sea_level': 1021.4,
#   '055_air_temperature': 18.1,
#   '055_cloud_area_fraction': 0.0,
#   '055_cloud_area_fraction_high': 0.0,
#   '055_cloud_area_fraction_low': 0.0,
#   '055_cloud_area_fraction_medium': 0.0,
#   '055_dew_point_temperature': -1.0,
#   '055_fog_area_fraction': 0.0,
#   '055_relative_humidity': 27.7,
#   '055_ultraviolet_index_clear_sky': 0.9,
#   '055_wind_from_direction': 96.9,
#   '055_wind_speed': 1.0,
#   '056_time': '2020-11-02T23:00:00Z',
#   '056_symbol_code': './images/png/clearsky_day.png',
#   '056_precipitation_amount': 0.0,
#   '056_air_pressure_at_sea_level': 1021.1,
#   '056_air_temperature': 17.2,
#   '056_cloud_area_fraction': 0.0,
#   '056_cloud_area_fraction_high': 0.0,
#   '056_cloud_area_fraction_low': 0.0,
#   '056_cloud_area_fraction_medium': 0.0,
#   '056_dew_point_temperature': 0.4,
#   '056_fog_area_fraction': 0.0,
#   '056_relative_humidity': 32.4,
#   '056_ultraviolet_index_clear_sky': 0.2,
#   '056_wind_from_direction': 110.1,
#   '056_wind_speed': 0.2,
#   '057_time': '2020-11-03T00:00:00Z',
#   '057_symbol_code': './images/png/clearsky_night.png',
#   '057_precipitation_amount': 0.0,
#   '057_air_pressure_at_sea_level': 1021.0,
#   '057_air_temperature': 12.9,
#   '057_cloud_area_fraction': 0.0,
#   '057_cloud_area_fraction_high': 0.0,
#   '057_cloud_area_fraction_low': 0.0,
#   '057_cloud_area_fraction_medium': 0.0,
#   '057_dew_point_temperature': 1.8,
#   '057_fog_area_fraction': 0.0,
#   '057_relative_humidity': 47.0,
#   '057_ultraviolet_index_clear_sky': 0.0,
#   '057_wind_from_direction': 265.9,
#   '057_wind_speed': 1.1,
#   '058_time': '2020-11-03T01:00:00Z',
#   '058_symbol_code': './images/png/clearsky_night.png',
#   '058_precipitation_amount': 0.0,
#   '058_air_pressure_at_sea_level': 1021.2,
#   '058_air_temperature': 10.3,
#   '058_cloud_area_fraction': 0.0,
#   '058_cloud_area_fraction_high': 0.0,
#   '058_cloud_area_fraction_low': 0.0,
#   '058_cloud_area_fraction_medium': 0.0,
#   '058_dew_point_temperature': 0.5,
#   '058_fog_area_fraction': 0.0,
#   '058_relative_humidity': 51.1,
#   '058_ultraviolet_index_clear_sky': 0.0,
#   '058_wind_from_direction': 266.6,
#   '058_wind_speed': 2.1,
#   '059_time': '2020-11-03T02:00:00Z',
#   '059_symbol_code': './images/png/clearsky_night.png',
#   '059_precipitation_amount': 0.0,
#   '059_air_pressure_at_sea_level': 1021.0,
#   '059_air_temperature': 8.6,
#   '059_cloud_area_fraction': 0.0,
#   '059_cloud_area_fraction_high': 0.0,
#   '059_cloud_area_fraction_low': 0.0,
#   '059_cloud_area_fraction_medium': 0.0,
#   '059_dew_point_temperature': -1.8,
#   '059_fog_area_fraction': 0.0,
#   '059_relative_humidity': 48.9,
#   '059_ultraviolet_index_clear_sky': 0.0,
#   '059_wind_from_direction': 266.5,
#   '059_wind_speed': 3.6,
#   '060_time': '2020-11-03T03:00:00Z',
#   '060_symbol_code': './images/png/clearsky_night.png',
#   '060_precipitation_amount': 0.0,
#   '060_air_pressure_at_sea_level': 1020.5,
#   '060_air_temperature': 8.5,
#   '060_cloud_area_fraction': 0.0,
#   '060_cloud_area_fraction_high': 0.0,
#   '060_cloud_area_fraction_low': 0.0,
#   '060_cloud_area_fraction_medium': 0.0,
#   '060_dew_point_temperature': -4.2,
#   '060_fog_area_fraction': 0.0,
#   '060_relative_humidity': 41.0,
#   '060_ultraviolet_index_clear_sky': 0.0,
#   '060_wind_from_direction': 268.1,
#   '060_wind_speed': 4.9,
#   '061_time': '2020-11-03T04:00:00Z',
#   '061_symbol_code': './images/png/clearsky_night.png',
#   '061_precipitation_amount': 0.0,
#   '061_air_pressure_at_sea_level': 1020.0,
#   '061_air_temperature': 8.7,
#   '061_cloud_area_fraction': 0.0,
#   '061_cloud_area_fraction_high': 0.0,
#   '061_cloud_area_fraction_low': 0.0,
#   '061_cloud_area_fraction_medium': 0.0,
#   '061_dew_point_temperature': -5.4,
#   '061_fog_area_fraction': 0.0,
#   '061_relative_humidity': 37.1,
#   '061_ultraviolet_index_clear_sky': 0.0,
#   '061_wind_from_direction': 267.8,
#   '061_wind_speed': 5.4,
#   '062_time': '2020-11-03T05:00:00Z',
#   '062_symbol_code': './images/png/clearsky_night.png',
#   '062_precipitation_amount': 0.0,
#   '062_air_pressure_at_sea_level': 1019.8,
#   '062_air_temperature': 8.1,
#   '062_cloud_area_fraction': 0.0,
#   '062_cloud_area_fraction_high': 0.0,
#   '062_cloud_area_fraction_low': 0.0,
#   '062_cloud_area_fraction_medium': 0.0,
#   '062_dew_point_temperature': -6.1,
#   '062_fog_area_fraction': 0.0,
#   '062_relative_humidity': 36.6,
#   '062_ultraviolet_index_clear_sky': 0.0,
#   '062_wind_from_direction': 266.9,
#   '062_wind_speed': 5.4,
#   '063_time': '2020-11-03T06:00:00Z',
#   '063_symbol_code': './images/png/None.png',
#   '063_precipitation_amount': None,
#   '063_air_pressure_at_sea_level': 1019.4,
#   '063_air_temperature': 7.7,
#   '063_cloud_area_fraction': 6.2,
#   '063_cloud_area_fraction_high': 6.2,
#   '063_cloud_area_fraction_low': 0.0,
#   '063_cloud_area_fraction_medium': 0.0,
#   '063_dew_point_temperature': -6.6,
#   '063_fog_area_fraction': 0.0,
#   '063_relative_humidity': 36.3,
#   '063_ultraviolet_index_clear_sky': 0.0,
#   '063_wind_from_direction': 267.7,
#   '063_wind_speed': 5.4,
#   '064_time': '2020-11-03T12:00:00Z',
#   '064_symbol_code': './images/png/None.png',
#   '064_precipitation_amount': None,
#   '064_air_pressure_at_sea_level': 1017.7,
#   '064_air_temperature': 8.0,
#   '064_cloud_area_fraction': 27.3,
#   '064_cloud_area_fraction_high': 21.1,
#   '064_cloud_area_fraction_low': 0.0,
#   '064_cloud_area_fraction_medium': 13.3,
#   '064_dew_point_temperature': -8.9,
#   '064_relative_humidity': 30.0,
#   '064_wind_from_direction': 272.9,
#   '064_wind_speed': 5.0,
#   '065_time': '2020-11-03T18:00:00Z',
#   '065_symbol_code': './images/png/None.png',
#   '065_precipitation_amount': None,
#   '065_air_pressure_at_sea_level': 1015.9,
#   '065_air_temperature': 20.5,
#   '065_cloud_area_fraction': 0.8,
#   '065_cloud_area_fraction_high': 0.8,
#   '065_cloud_area_fraction_low': 0.0,
#   '065_cloud_area_fraction_medium': 0.8,
#   '065_dew_point_temperature': -2.4,
#   '065_relative_humidity': 21.5,
#   '065_wind_from_direction': 21.6,
#   '065_wind_speed': 1.6,
#   '066_time': '2020-11-04T00:00:00Z',
#   '066_symbol_code': './images/png/None.png',
#   '066_precipitation_amount': None,
#   '066_air_pressure_at_sea_level': 1014.4,
#   '066_air_temperature': 12.8,
#   '066_cloud_area_fraction': 33.6,
#   '066_cloud_area_fraction_high': 6.2,
#   '066_cloud_area_fraction_low': 0.0,
#   '066_cloud_area_fraction_medium': 33.6,
#   '066_dew_point_temperature': 0.0,
#   '066_relative_humidity': 41.9,
#   '066_wind_from_direction': 254.9,
#   '066_wind_speed': 1.9,
#   ...},
#  1)

# %%
self = SelfDummy()
self.config = {'lat': coord[0], 'lon': coord[1],
               'forecasts': [0, 6, 12, 24]}

# %%
r = requests.get(f"{constants.yr_endpoint}lat={self.config['lat']}&lon={self.config['lon']}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.met.no:443
# DEBUG:urllib3.connectionpool:https://api.met.no:443 "GET /weatherapi/locationforecast/2.0/complete.json?lat=39.755543&lon=-105.2210997 HTTP/1.1" 200 3804

# %%
r.status_code
# Out:
# 200

# %%
meta = dictor(r.json(), 'properties.meta')

# %%
meta
# Out:
# {'updated_at': '2020-10-31T13:27:08Z',
#  'units': {'air_pressure_at_sea_level': 'hPa',
#   'air_temperature': 'celsius',
#   'air_temperature_max': 'celsius',
#   'air_temperature_min': 'celsius',
#   'cloud_area_fraction': '%',
#   'cloud_area_fraction_high': '%',
#   'cloud_area_fraction_low': '%',
#   'cloud_area_fraction_medium': '%',
#   'dew_point_temperature': 'celsius',
#   'fog_area_fraction': '%',
#   'precipitation_amount': 'mm',
#   'relative_humidity': '%',
#   'ultraviolet_index_clear_sky': '1',
#   'wind_from_direction': 'degrees',
#   'wind_speed': 'm/s'}}

# %%
timeseries = dictor(r.json(), 'properties.timeseries')

# %%
timeseries[0]
# Out:
# {'time': '2020-10-31T15:00:00Z',
#  'data': {'instant': {'details': {'air_pressure_at_sea_level': 1017.3,
#     'air_temperature': 6.6,
#     'cloud_area_fraction': 0.0,
#     'cloud_area_fraction_high': 0.0,
#     'cloud_area_fraction_low': 0.0,
#     'cloud_area_fraction_medium': 0.0,
#     'dew_point_temperature': -3.0,
#     'fog_area_fraction': 0.0,
#     'relative_humidity': 51.3,
#     'ultraviolet_index_clear_sky': 0.8,
#     'wind_from_direction': 278.4,
#     'wind_speed': 3.2}},
#   'next_12_hours': {'summary': {'symbol_code': 'clearsky_day'}},
#   'next_1_hours': {'summary': {'symbol_code': 'clearsky_day'},
#    'details': {'precipitation_amount': 0.0}},
#   'next_6_hours': {'summary': {'symbol_code': 'clearsky_day'},
#    'details': {'air_temperature_max': 15.5,
#     'air_temperature_min': 11.3,
#     'precipitation_amount': 0.0}}}}

# %%
# def flatten_json(y):
#     out = {}

#     def flatten(x, name=''):
#         if type(x) is dict:
#             for a in x:
#                 flatten(x[a], name + a + '_')
#         elif type(x) is list:
#             i = 0
#             for a in x:
#                 flatten(a, name + str(i) + '_')
#                 i += 1
#         else:
#             out[name[:-1]] = x

#     flatten(y)
#     return out

# %%
def flatten_json(y):
    out = {}
    
    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], f"{name}{a}_")
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, f"{name}{i:03}_")
                i += 1
        else:
            out[name[:-1]] = (x, None)

    flatten(y)
    return out

# %%
def flatten_json(y):
    out = {}
    
    t = {'air_temperature': 'celcius',
         'precipitation_amount': 'mm'}
    
    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], f"{name}{a}_")
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, f"{name}{i:03}_")
                i += 1
        else:
            out[name[:-1]] = [x]

    flatten(y)
    return out

# %%
abreviations = {'celsius': 'C',
                'farenheit': 'F',
                None: ''
                }

# %%
f_meta = flatten_json(meta['units'])

# %%
for meta_k in f_meta:
    if f_meta[meta_k][0] in abreviations.keys():
        append_val = abreviations[f_meta[meta_k][0]]
    else:
        append_val = f_meta[meta_k][0]
    f_meta[meta_k].append(append_val)

# %%
f_meta
# Out:
# {'air_pressure_at_sea_level': ['hPa', 'hPa'],
#  'air_temperature': ['celsius', 'C'],
#  'air_temperature_max': ['celsius', 'C'],
#  'air_temperature_min': ['celsius', 'C'],
#  'cloud_area_fraction': ['%', '%'],
#  'cloud_area_fraction_high': ['%', '%'],
#  'cloud_area_fraction_low': ['%', '%'],
#  'cloud_area_fraction_medium': ['%', '%'],
#  'dew_point_temperature': ['celsius', 'C'],
#  'fog_area_fraction': ['%', '%'],
#  'precipitation_amount': ['mm', 'mm'],
#  'relative_humidity': ['%', '%'],
#  'ultraviolet_index_clear_sky': ['1', '1'],
#  'wind_from_direction': ['degrees', 'degrees'],
#  'wind_speed': ['m/s', 'm/s']}

# %%
f_timeseries = flatten_json(timeseries)

# %%
f_timeseries
# Out:
# {'000_time': ['2020-10-31T15:00:00Z', None],
#  '000_data_instant_details_air_pressure_at_sea_level': [1017.3, None],
#  '000_data_instant_details_air_temperature': [6.6, None],
#  '000_data_instant_details_cloud_area_fraction': [0.0, None],
#  '000_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '000_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '000_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '000_data_instant_details_dew_point_temperature': [-3.0, None],
#  '000_data_instant_details_fog_area_fraction': [0.0, None],
#  '000_data_instant_details_relative_humidity': [51.3, None],
#  '000_data_instant_details_ultraviolet_index_clear_sky': [0.8, None],
#  '000_data_instant_details_wind_from_direction': [278.4, None],
#  '000_data_instant_details_wind_speed': [3.2, None],
#  '000_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '000_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_6_hours_details_air_temperature_max': [15.5, None],
#  '000_data_next_6_hours_details_air_temperature_min': [11.3, None],
#  '000_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '001_time': ['2020-10-31T16:00:00Z', None],
#  '001_data_instant_details_air_pressure_at_sea_level': [1018.1, None],
#  '001_data_instant_details_air_temperature': [12.7, None],
#  '001_data_instant_details_cloud_area_fraction': [1.6, None],
#  '001_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '001_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '001_data_instant_details_cloud_area_fraction_medium': [1.6, None],
#  '001_data_instant_details_dew_point_temperature': [-3.5, None],
#  '001_data_instant_details_fog_area_fraction': [0.0, None],
#  '001_data_instant_details_relative_humidity': [32.7, None],
#  '001_data_instant_details_ultraviolet_index_clear_sky': [1.9, None],
#  '001_data_instant_details_wind_from_direction': [227.4, None],
#  '001_data_instant_details_wind_speed': [1.2, None],
#  '001_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '001_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_6_hours_details_air_temperature_max': [15.5, None],
#  '001_data_next_6_hours_details_air_temperature_min': [9.9, None],
#  '001_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '002_time': ['2020-10-31T17:00:00Z', None],
#  '002_data_instant_details_air_pressure_at_sea_level': [1018.6, None],
#  '002_data_instant_details_air_temperature': [13.7, None],
#  '002_data_instant_details_cloud_area_fraction': [0.8, None],
#  '002_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '002_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '002_data_instant_details_cloud_area_fraction_medium': [0.8, None],
#  '002_data_instant_details_dew_point_temperature': [-4.5, None],
#  '002_data_instant_details_fog_area_fraction': [0.0, None],
#  '002_data_instant_details_relative_humidity': [28.4, None],
#  '002_data_instant_details_ultraviolet_index_clear_sky': [3.3, None],
#  '002_data_instant_details_wind_from_direction': [84.8, None],
#  '002_data_instant_details_wind_speed': [1.8, None],
#  '002_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '002_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_6_hours_details_air_temperature_max': [15.5, None],
#  '002_data_next_6_hours_details_air_temperature_min': [8.6, None],
#  '002_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '003_time': ['2020-10-31T18:00:00Z', None],
#  '003_data_instant_details_air_pressure_at_sea_level': [1019.6, None],
#  '003_data_instant_details_air_temperature': [14.7, None],
#  '003_data_instant_details_cloud_area_fraction': [0.8, None],
#  '003_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '003_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '003_data_instant_details_cloud_area_fraction_medium': [0.8, None],
#  '003_data_instant_details_dew_point_temperature': [-4.0, None],
#  '003_data_instant_details_fog_area_fraction': [0.0, None],
#  '003_data_instant_details_relative_humidity': [27.8, None],
#  '003_data_instant_details_ultraviolet_index_clear_sky': [4.2, None],
#  '003_data_instant_details_wind_from_direction': [31.5, None],
#  '003_data_instant_details_wind_speed': [1.4, None],
#  '003_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '003_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '003_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '003_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '003_data_next_6_hours_details_air_temperature_max': [15.5, None],
#  '003_data_next_6_hours_details_air_temperature_min': [5.1, None],
#  '003_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '004_time': ['2020-10-31T19:00:00Z', None],
#  '004_data_instant_details_air_pressure_at_sea_level': [1020.3, None],
#  '004_data_instant_details_air_temperature': [15.5, None],
#  '004_data_instant_details_cloud_area_fraction': [0.8, None],
#  '004_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '004_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '004_data_instant_details_cloud_area_fraction_medium': [0.8, None],
#  '004_data_instant_details_dew_point_temperature': [-4.9, None],
#  '004_data_instant_details_fog_area_fraction': [0.0, None],
#  '004_data_instant_details_relative_humidity': [24.6, None],
#  '004_data_instant_details_ultraviolet_index_clear_sky': [4.2, None],
#  '004_data_instant_details_wind_from_direction': [345.9, None],
#  '004_data_instant_details_wind_speed': [4.0, None],
#  '004_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '004_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '004_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '004_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '004_data_next_6_hours_details_air_temperature_max': [12.2, None],
#  '004_data_next_6_hours_details_air_temperature_min': [4.3, None],
#  '004_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '005_time': ['2020-10-31T20:00:00Z', None],
#  '005_data_instant_details_air_pressure_at_sea_level': [1022.6, None],
#  '005_data_instant_details_air_temperature': [12.2, None],
#  '005_data_instant_details_cloud_area_fraction': [0.0, None],
#  '005_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '005_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '005_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '005_data_instant_details_dew_point_temperature': [-1.9, None],
#  '005_data_instant_details_fog_area_fraction': [0.0, None],
#  '005_data_instant_details_relative_humidity': [38.1, None],
#  '005_data_instant_details_ultraviolet_index_clear_sky': [3.4, None],
#  '005_data_instant_details_wind_from_direction': [28.9, None],
#  '005_data_instant_details_wind_speed': [5.1, None],
#  '005_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '005_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '005_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '005_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '005_data_next_6_hours_details_air_temperature_max': [11.3, None],
#  '005_data_next_6_hours_details_air_temperature_min': [3.5, None],
#  '005_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '006_time': ['2020-10-31T21:00:00Z', None],
#  '006_data_instant_details_air_pressure_at_sea_level': [1024.1, None],
#  '006_data_instant_details_air_temperature': [11.3, None],
#  '006_data_instant_details_cloud_area_fraction': [0.0, None],
#  '006_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '006_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '006_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '006_data_instant_details_dew_point_temperature': [-1.4, None],
#  '006_data_instant_details_fog_area_fraction': [0.0, None],
#  '006_data_instant_details_relative_humidity': [41.7, None],
#  '006_data_instant_details_ultraviolet_index_clear_sky': [2.1, None],
#  '006_data_instant_details_wind_from_direction': [41.2, None],
#  '006_data_instant_details_wind_speed': [4.2, None],
#  '006_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '006_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '006_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '006_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '006_data_next_6_hours_details_air_temperature_max': [9.9, None],
#  '006_data_next_6_hours_details_air_temperature_min': [2.8, None],
#  '006_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '007_time': ['2020-10-31T22:00:00Z', None],
#  '007_data_instant_details_air_pressure_at_sea_level': [1025.9, None],
#  '007_data_instant_details_air_temperature': [9.9, None],
#  '007_data_instant_details_cloud_area_fraction': [0.0, None],
#  '007_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '007_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '007_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '007_data_instant_details_dew_point_temperature': [-1.5, None],
#  '007_data_instant_details_fog_area_fraction': [0.0, None],
#  '007_data_instant_details_relative_humidity': [45.5, None],
#  '007_data_instant_details_ultraviolet_index_clear_sky': [0.9, None],
#  '007_data_instant_details_wind_from_direction': [53.3, None],
#  '007_data_instant_details_wind_speed': [3.6, None],
#  '007_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '007_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '007_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '007_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '007_data_next_6_hours_details_air_temperature_max': [8.6, None],
#  '007_data_next_6_hours_details_air_temperature_min': [2.0, None],
#  '007_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '008_time': ['2020-10-31T23:00:00Z', None],
#  '008_data_instant_details_air_pressure_at_sea_level': [1027.1, None],
#  '008_data_instant_details_air_temperature': [8.6, None],
#  '008_data_instant_details_cloud_area_fraction': [0.0, None],
#  '008_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '008_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '008_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '008_data_instant_details_dew_point_temperature': [-1.7, None],
#  '008_data_instant_details_fog_area_fraction': [0.0, None],
#  '008_data_instant_details_relative_humidity': [49.0, None],
#  '008_data_instant_details_ultraviolet_index_clear_sky': [0.2, None],
#  '008_data_instant_details_wind_from_direction': [75.4, None],
#  '008_data_instant_details_wind_speed': [1.7, None],
#  '008_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '008_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '008_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '008_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '008_data_next_6_hours_details_air_temperature_max': [5.1, None],
#  '008_data_next_6_hours_details_air_temperature_min': [0.9, None],
#  '008_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '009_time': ['2020-11-01T00:00:00Z', None],
#  '009_data_instant_details_air_pressure_at_sea_level': [1027.9, None],
#  '009_data_instant_details_air_temperature': [5.1, None],
#  '009_data_instant_details_cloud_area_fraction': [0.0, None],
#  '009_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '009_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '009_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '009_data_instant_details_dew_point_temperature': [-1.4, None],
#  '009_data_instant_details_fog_area_fraction': [0.0, None],
#  '009_data_instant_details_relative_humidity': [63.6, None],
#  '009_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '009_data_instant_details_wind_from_direction': [215.1, None],
#  '009_data_instant_details_wind_speed': [1.4, None],
#  '009_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '009_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_6_hours_details_air_temperature_max': [4.3, None],
#  '009_data_next_6_hours_details_air_temperature_min': [0.3, None],
#  '009_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '010_time': ['2020-11-01T01:00:00Z', None],
#  '010_data_instant_details_air_pressure_at_sea_level': [1028.6, None],
#  '010_data_instant_details_air_temperature': [4.3, None],
#  '010_data_instant_details_cloud_area_fraction': [0.0, None],
#  '010_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '010_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '010_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '010_data_instant_details_dew_point_temperature': [-1.6, None],
#  '010_data_instant_details_fog_area_fraction': [0.0, None],
#  '010_data_instant_details_relative_humidity': [66.7, None],
#  '010_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '010_data_instant_details_wind_from_direction': [241.4, None],
#  '010_data_instant_details_wind_speed': [1.4, None],
#  '010_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '010_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_6_hours_details_air_temperature_max': [3.5, None],
#  '010_data_next_6_hours_details_air_temperature_min': [0.2, None],
#  '010_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '011_time': ['2020-11-01T02:00:00Z', None],
#  '011_data_instant_details_air_pressure_at_sea_level': [1029.7, None],
#  '011_data_instant_details_air_temperature': [3.5, None],
#  '011_data_instant_details_cloud_area_fraction': [0.0, None],
#  '011_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '011_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '011_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '011_data_instant_details_dew_point_temperature': [-1.8, None],
#  '011_data_instant_details_fog_area_fraction': [0.0, None],
#  '011_data_instant_details_relative_humidity': [69.2, None],
#  '011_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '011_data_instant_details_wind_from_direction': [232.1, None],
#  '011_data_instant_details_wind_speed': [1.3, None],
#  '011_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '011_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_6_hours_details_air_temperature_max': [2.8, None],
#  '011_data_next_6_hours_details_air_temperature_min': [0.0, None],
#  '011_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '012_time': ['2020-11-01T03:00:00Z', None],
#  '012_data_instant_details_air_pressure_at_sea_level': [1029.9, None],
#  '012_data_instant_details_air_temperature': [2.8, None],
#  '012_data_instant_details_cloud_area_fraction': [0.0, None],
#  '012_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '012_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '012_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '012_data_instant_details_dew_point_temperature': [-1.9, None],
#  '012_data_instant_details_fog_area_fraction': [0.0, None],
#  '012_data_instant_details_relative_humidity': [72.2, None],
#  '012_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '012_data_instant_details_wind_from_direction': [235.6, None],
#  '012_data_instant_details_wind_speed': [1.5, None],
#  '012_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '012_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_6_hours_details_air_temperature_max': [2.0, None],
#  '012_data_next_6_hours_details_air_temperature_min': [-0.1, None],
#  '012_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '013_time': ['2020-11-01T04:00:00Z', None],
#  '013_data_instant_details_air_pressure_at_sea_level': [1030.2, None],
#  '013_data_instant_details_air_temperature': [2.0, None],
#  '013_data_instant_details_cloud_area_fraction': [0.0, None],
#  '013_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '013_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '013_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '013_data_instant_details_dew_point_temperature': [-2.6, None],
#  '013_data_instant_details_fog_area_fraction': [0.0, None],
#  '013_data_instant_details_relative_humidity': [73.0, None],
#  '013_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '013_data_instant_details_wind_from_direction': [233.9, None],
#  '013_data_instant_details_wind_speed': [1.6, None],
#  '013_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '013_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_6_hours_details_air_temperature_max': [0.9, None],
#  '013_data_next_6_hours_details_air_temperature_min': [-0.1, None],
#  '013_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '014_time': ['2020-11-01T05:00:00Z', None],
#  '014_data_instant_details_air_pressure_at_sea_level': [1030.5, None],
#  '014_data_instant_details_air_temperature': [0.9, None],
#  '014_data_instant_details_cloud_area_fraction': [0.0, None],
#  '014_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '014_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '014_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '014_data_instant_details_dew_point_temperature': [-3.9, None],
#  '014_data_instant_details_fog_area_fraction': [0.0, None],
#  '014_data_instant_details_relative_humidity': [71.6, None],
#  '014_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '014_data_instant_details_wind_from_direction': [253.5, None],
#  '014_data_instant_details_wind_speed': [1.8, None],
#  '014_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '014_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_6_hours_details_air_temperature_max': [0.6, None],
#  '014_data_next_6_hours_details_air_temperature_min': [-0.1, None],
#  '014_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '015_time': ['2020-11-01T06:00:00Z', None],
#  '015_data_instant_details_air_pressure_at_sea_level': [1030.3, None],
#  '015_data_instant_details_air_temperature': [0.3, None],
#  '015_data_instant_details_cloud_area_fraction': [0.0, None],
#  '015_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '015_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '015_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '015_data_instant_details_dew_point_temperature': [-5.5, None],
#  '015_data_instant_details_fog_area_fraction': [0.0, None],
#  '015_data_instant_details_relative_humidity': [66.6, None],
#  '015_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '015_data_instant_details_wind_from_direction': [262.1, None],
#  '015_data_instant_details_wind_speed': [2.0, None],
#  '015_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '015_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_6_hours_details_air_temperature_max': [0.6, None],
#  '015_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '015_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '016_time': ['2020-11-01T07:00:00Z', None],
#  '016_data_instant_details_air_pressure_at_sea_level': [1029.3, None],
#  '016_data_instant_details_air_temperature': [0.2, None],
#  '016_data_instant_details_cloud_area_fraction': [0.0, None],
#  '016_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '016_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '016_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '016_data_instant_details_dew_point_temperature': [-6.7, None],
#  '016_data_instant_details_fog_area_fraction': [0.0, None],
#  '016_data_instant_details_relative_humidity': [61.0, None],
#  '016_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '016_data_instant_details_wind_from_direction': [256.6, None],
#  '016_data_instant_details_wind_speed': [2.3, None],
#  '016_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '016_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_6_hours_details_air_temperature_max': [0.6, None],
#  '016_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '016_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '017_time': ['2020-11-01T08:00:00Z', None],
#  '017_data_instant_details_air_pressure_at_sea_level': [1028.5, None],
#  '017_data_instant_details_air_temperature': [0.0, None],
#  '017_data_instant_details_cloud_area_fraction': [0.0, None],
#  '017_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '017_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '017_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '017_data_instant_details_dew_point_temperature': [-7.5, None],
#  '017_data_instant_details_fog_area_fraction': [0.0, None],
#  '017_data_instant_details_relative_humidity': [58.4, None],
#  '017_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '017_data_instant_details_wind_from_direction': [265.4, None],
#  '017_data_instant_details_wind_speed': [2.3, None],
#  '017_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '017_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '017_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '017_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '017_data_next_6_hours_details_air_temperature_max': [1.0, None],
#  '017_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '017_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '018_time': ['2020-11-01T09:00:00Z', None],
#  '018_data_instant_details_air_pressure_at_sea_level': [1028.3, None],
#  '018_data_instant_details_air_temperature': [-0.1, None],
#  '018_data_instant_details_cloud_area_fraction': [0.0, None],
#  '018_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '018_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '018_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '018_data_instant_details_dew_point_temperature': [-7.6, None],
#  '018_data_instant_details_fog_area_fraction': [0.0, None],
#  '018_data_instant_details_relative_humidity': [58.6, None],
#  '018_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '018_data_instant_details_wind_from_direction': [273.4, None],
#  '018_data_instant_details_wind_speed': [2.9, None],
#  '018_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '018_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '018_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '018_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '018_data_next_6_hours_details_air_temperature_max': [5.9, None],
#  '018_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '018_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '019_time': ['2020-11-01T10:00:00Z', None],
#  '019_data_instant_details_air_pressure_at_sea_level': [1028.0, None],
#  '019_data_instant_details_air_temperature': [0.6, None],
#  '019_data_instant_details_cloud_area_fraction': [0.0, None],
#  '019_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '019_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '019_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '019_data_instant_details_dew_point_temperature': [-7.8, None],
#  '019_data_instant_details_fog_area_fraction': [0.0, None],
#  '019_data_instant_details_relative_humidity': [54.7, None],
#  '019_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '019_data_instant_details_wind_from_direction': [278.7, None],
#  '019_data_instant_details_wind_speed': [3.4, None],
#  '019_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '019_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '019_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '019_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '019_data_next_6_hours_details_air_temperature_max': [10.5, None],
#  '019_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '019_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '020_time': ['2020-11-01T11:00:00Z', None],
#  '020_data_instant_details_air_pressure_at_sea_level': [1028.2, None],
#  '020_data_instant_details_air_temperature': [0.4, None],
#  '020_data_instant_details_cloud_area_fraction': [0.0, None],
#  '020_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '020_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '020_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '020_data_instant_details_dew_point_temperature': [-8.4, None],
#  '020_data_instant_details_fog_area_fraction': [0.0, None],
#  '020_data_instant_details_relative_humidity': [53.1, None],
#  '020_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '020_data_instant_details_wind_from_direction': [274.2, None],
#  '020_data_instant_details_wind_speed': [2.7, None],
#  '020_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '020_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '020_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '020_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '020_data_next_6_hours_details_air_temperature_max': [12.4, None],
#  '020_data_next_6_hours_details_air_temperature_min': [-0.2, None],
#  '020_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '021_time': ['2020-11-01T12:00:00Z', None],
#  '021_data_instant_details_air_pressure_at_sea_level': [1028.8, None],
#  '021_data_instant_details_air_temperature': [-0.2, None],
#  '021_data_instant_details_cloud_area_fraction': [0.0, None],
#  '021_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '021_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '021_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '021_data_instant_details_dew_point_temperature': [-8.9, None],
#  '021_data_instant_details_fog_area_fraction': [0.0, None],
#  '021_data_instant_details_relative_humidity': [53.4, None],
#  '021_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '021_data_instant_details_wind_from_direction': [264.5, None],
#  '021_data_instant_details_wind_speed': [2.3, None],
#  '021_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '021_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '021_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '021_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '021_data_next_6_hours_details_air_temperature_max': [14.2, None],
#  '021_data_next_6_hours_details_air_temperature_min': [-0.1, None],
#  '021_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '022_time': ['2020-11-01T13:00:00Z', None],
#  '022_data_instant_details_air_pressure_at_sea_level': [1028.6, None],
#  '022_data_instant_details_air_temperature': [-0.1, None],
#  '022_data_instant_details_cloud_area_fraction': [0.8, None],
#  '022_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '022_data_instant_details_cloud_area_fraction_low': [0.8, None],
#  '022_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '022_data_instant_details_dew_point_temperature': [-9.4, None],
#  '022_data_instant_details_fog_area_fraction': [0.0, None],
#  '022_data_instant_details_relative_humidity': [51.2, None],
#  '022_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '022_data_instant_details_wind_from_direction': [263.4, None],
#  '022_data_instant_details_wind_speed': [2.6, None],
#  '022_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '022_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '022_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '022_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '022_data_next_6_hours_details_air_temperature_max': [15.1, None],
#  '022_data_next_6_hours_details_air_temperature_min': [1.0, None],
#  '022_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '023_time': ['2020-11-01T14:00:00Z', None],
#  '023_data_instant_details_air_pressure_at_sea_level': [1028.4, None],
#  '023_data_instant_details_air_temperature': [1.0, None],
#  '023_data_instant_details_cloud_area_fraction': [1.6, None],
#  '023_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '023_data_instant_details_cloud_area_fraction_low': [1.6, None],
#  '023_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '023_data_instant_details_dew_point_temperature': [-8.8, None],
#  '023_data_instant_details_fog_area_fraction': [0.0, None],
#  '023_data_instant_details_relative_humidity': [49.5, None],
#  '023_data_instant_details_ultraviolet_index_clear_sky': [0.1, None],
#  '023_data_instant_details_wind_from_direction': [259.6, None],
#  '023_data_instant_details_wind_speed': [2.7, None],
#  '023_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '023_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_6_hours_details_air_temperature_max': [15.5, None],
#  '023_data_next_6_hours_details_air_temperature_min': [5.9, None],
#  '023_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '024_time': ['2020-11-01T15:00:00Z', None],
#  '024_data_instant_details_air_pressure_at_sea_level': [1028.6, None],
#  '024_data_instant_details_air_temperature': [5.9, None],
#  '024_data_instant_details_cloud_area_fraction': [0.8, None],
#  '024_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '024_data_instant_details_cloud_area_fraction_low': [0.8, None],
#  '024_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '024_data_instant_details_dew_point_temperature': [-6.1, None],
#  '024_data_instant_details_fog_area_fraction': [0.0, None],
#  '024_data_instant_details_relative_humidity': [42.9, None],
#  '024_data_instant_details_ultraviolet_index_clear_sky': [0.7, None],
#  '024_data_instant_details_wind_from_direction': [239.3, None],
#  '024_data_instant_details_wind_speed': [2.6, None],
#  '024_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '024_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '024_data_next_6_hours_details_air_temperature_min': [10.5, None],
#  '024_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '025_time': ['2020-11-01T16:00:00Z', None],
#  '025_data_instant_details_air_pressure_at_sea_level': [1028.2, None],
#  '025_data_instant_details_air_temperature': [10.5, None],
#  '025_data_instant_details_cloud_area_fraction': [0.0, None],
#  '025_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '025_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '025_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '025_data_instant_details_dew_point_temperature': [-4.6, None],
#  '025_data_instant_details_fog_area_fraction': [0.0, None],
#  '025_data_instant_details_relative_humidity': [34.9, None],
#  '025_data_instant_details_ultraviolet_index_clear_sky': [1.9, None],
#  '025_data_instant_details_wind_from_direction': [156.3, None],
#  '025_data_instant_details_wind_speed': [2.0, None],
#  '025_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '025_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '025_data_next_6_hours_details_air_temperature_min': [12.4, None],
#  '025_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '026_time': ['2020-11-01T17:00:00Z', None],
#  '026_data_instant_details_air_pressure_at_sea_level': [1027.9, None],
#  '026_data_instant_details_air_temperature': [12.4, None],
#  '026_data_instant_details_cloud_area_fraction': [0.0, None],
#  '026_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '026_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '026_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '026_data_instant_details_dew_point_temperature': [-5.9, None],
#  '026_data_instant_details_fog_area_fraction': [0.0, None],
#  '026_data_instant_details_relative_humidity': [28.0, None],
#  '026_data_instant_details_ultraviolet_index_clear_sky': [3.2, None],
#  '026_data_instant_details_wind_from_direction': [138.1, None],
#  '026_data_instant_details_wind_speed': [2.1, None],
#  '026_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '026_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '026_data_next_6_hours_details_air_temperature_min': [13.4, None],
#  '026_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '027_time': ['2020-11-01T18:00:00Z', None],
#  '027_data_instant_details_air_pressure_at_sea_level': [1027.2, None],
#  '027_data_instant_details_air_temperature': [14.2, None],
#  '027_data_instant_details_cloud_area_fraction': [0.0, None],
#  '027_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '027_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '027_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '027_data_instant_details_dew_point_temperature': [-7.3, None],
#  '027_data_instant_details_fog_area_fraction': [0.0, None],
#  '027_data_instant_details_relative_humidity': [22.5, None],
#  '027_data_instant_details_ultraviolet_index_clear_sky': [4.2, None],
#  '027_data_instant_details_wind_from_direction': [130.3, None],
#  '027_data_instant_details_wind_speed': [1.9, None],
#  '027_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '027_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '027_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '027_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '027_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '027_data_next_6_hours_details_air_temperature_min': [11.8, None],
#  '027_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '028_time': ['2020-11-01T19:00:00Z', None],
#  '028_data_instant_details_air_pressure_at_sea_level': [1026.4, None],
#  '028_data_instant_details_air_temperature': [15.1, None],
#  '028_data_instant_details_cloud_area_fraction': [0.0, None],
#  '028_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '028_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '028_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '028_data_instant_details_dew_point_temperature': [-6.6, None],
#  '028_data_instant_details_fog_area_fraction': [0.0, None],
#  '028_data_instant_details_relative_humidity': [22.3, None],
#  '028_data_instant_details_ultraviolet_index_clear_sky': [4.2, None],
#  '028_data_instant_details_wind_from_direction': [113.1, None],
#  '028_data_instant_details_wind_speed': [2.1, None],
#  '028_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '028_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '028_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '028_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '028_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '028_data_next_6_hours_details_air_temperature_min': [11.2, None],
#  '028_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '029_time': ['2020-11-01T20:00:00Z', None],
#  '029_data_instant_details_air_pressure_at_sea_level': [1025.7, None],
#  '029_data_instant_details_air_temperature': [15.5, None],
#  '029_data_instant_details_cloud_area_fraction': [0.0, None],
#  '029_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '029_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '029_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '029_data_instant_details_dew_point_temperature': [-5.4, None],
#  '029_data_instant_details_fog_area_fraction': [0.0, None],
#  '029_data_instant_details_relative_humidity': [23.8, None],
#  '029_data_instant_details_ultraviolet_index_clear_sky': [3.5, None],
#  '029_data_instant_details_wind_from_direction': [110.5, None],
#  '029_data_instant_details_wind_speed': [1.9, None],
#  '029_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '029_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '029_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '029_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '029_data_next_6_hours_details_air_temperature_max': [15.7, None],
#  '029_data_next_6_hours_details_air_temperature_min': [6.4, None],
#  '029_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '030_time': ['2020-11-01T21:00:00Z', None],
#  '030_data_instant_details_air_pressure_at_sea_level': [1025.3, None],
#  '030_data_instant_details_air_temperature': [15.7, None],
#  '030_data_instant_details_cloud_area_fraction': [0.0, None],
#  '030_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '030_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '030_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '030_data_instant_details_dew_point_temperature': [-4.5, None],
#  '030_data_instant_details_fog_area_fraction': [0.0, None],
#  '030_data_instant_details_relative_humidity': [25.1, None],
#  '030_data_instant_details_ultraviolet_index_clear_sky': [2.2, None],
#  '030_data_instant_details_wind_from_direction': [112.7, None],
#  '030_data_instant_details_wind_speed': [1.5, None],
#  '030_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '030_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '030_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '030_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '030_data_next_6_hours_details_air_temperature_max': [15.4, None],
#  '030_data_next_6_hours_details_air_temperature_min': [5.3, None],
#  '030_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '031_time': ['2020-11-01T22:00:00Z', None],
#  '031_data_instant_details_air_pressure_at_sea_level': [1025.4, None],
#  '031_data_instant_details_air_temperature': [15.4, None],
#  '031_data_instant_details_cloud_area_fraction': [0.0, None],
#  '031_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '031_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '031_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '031_data_instant_details_dew_point_temperature': [-3.2, None],
#  '031_data_instant_details_fog_area_fraction': [0.0, None],
#  '031_data_instant_details_relative_humidity': [28.2, None],
#  '031_data_instant_details_ultraviolet_index_clear_sky': [0.9, None],
#  '031_data_instant_details_wind_from_direction': [113.5, None],
#  '031_data_instant_details_wind_speed': [1.4, None],
#  '031_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '031_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '031_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '031_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '031_data_next_6_hours_details_air_temperature_max': [13.4, None],
#  '031_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '031_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '032_time': ['2020-11-01T23:00:00Z', None],
#  '032_data_instant_details_air_pressure_at_sea_level': [1025.5, None],
#  '032_data_instant_details_air_temperature': [13.4, None],
#  '032_data_instant_details_cloud_area_fraction': [0.0, None],
#  '032_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '032_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '032_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '032_data_instant_details_dew_point_temperature': [4.9, None],
#  '032_data_instant_details_fog_area_fraction': [0.0, None],
#  '032_data_instant_details_relative_humidity': [56.8, None],
#  '032_data_instant_details_ultraviolet_index_clear_sky': [0.2, None],
#  '032_data_instant_details_wind_from_direction': [109.7, None],
#  '032_data_instant_details_wind_speed': [1.1, None],
#  '032_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '032_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '032_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '032_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '032_data_next_6_hours_details_air_temperature_max': [11.8, None],
#  '032_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '032_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '033_time': ['2020-11-02T00:00:00Z', None],
#  '033_data_instant_details_air_pressure_at_sea_level': [1025.7, None],
#  '033_data_instant_details_air_temperature': [11.8, None],
#  '033_data_instant_details_cloud_area_fraction': [0.0, None],
#  '033_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '033_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '033_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '033_data_instant_details_dew_point_temperature': [-1.1, None],
#  '033_data_instant_details_fog_area_fraction': [0.0, None],
#  '033_data_instant_details_relative_humidity': [41.3, None],
#  '033_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '033_data_instant_details_wind_from_direction': [262.6, None],
#  '033_data_instant_details_wind_speed': [0.7, None],
#  '033_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '033_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_6_hours_details_air_temperature_max': [11.2, None],
#  '033_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '033_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '034_time': ['2020-11-02T01:00:00Z', None],
#  '034_data_instant_details_air_pressure_at_sea_level': [1026.4, None],
#  '034_data_instant_details_air_temperature': [11.2, None],
#  '034_data_instant_details_cloud_area_fraction': [0.0, None],
#  '034_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '034_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '034_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '034_data_instant_details_dew_point_temperature': [-1.9, None],
#  '034_data_instant_details_fog_area_fraction': [0.0, None],
#  '034_data_instant_details_relative_humidity': [40.8, None],
#  '034_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '034_data_instant_details_wind_from_direction': [263.8, None],
#  '034_data_instant_details_wind_speed': [0.3, None],
#  '034_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '034_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_6_hours_details_air_temperature_max': [6.5, None],
#  '034_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '034_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '035_time': ['2020-11-02T02:00:00Z', None],
#  '035_data_instant_details_air_pressure_at_sea_level': [1027.1, None],
#  '035_data_instant_details_air_temperature': [6.4, None],
#  '035_data_instant_details_cloud_area_fraction': [0.0, None],
#  '035_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '035_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '035_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '035_data_instant_details_dew_point_temperature': [-1.9, None],
#  '035_data_instant_details_fog_area_fraction': [0.0, None],
#  '035_data_instant_details_relative_humidity': [55.8, None],
#  '035_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '035_data_instant_details_wind_from_direction': [263.3, None],
#  '035_data_instant_details_wind_speed': [1.7, None],
#  '035_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '035_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_6_hours_details_air_temperature_max': [6.8, None],
#  '035_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '035_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '036_time': ['2020-11-02T03:00:00Z', None],
#  '036_data_instant_details_air_pressure_at_sea_level': [1027.3, None],
#  '036_data_instant_details_air_temperature': [5.3, None],
#  '036_data_instant_details_cloud_area_fraction': [0.0, None],
#  '036_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '036_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '036_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '036_data_instant_details_dew_point_temperature': [-3.7, None],
#  '036_data_instant_details_fog_area_fraction': [0.0, None],
#  '036_data_instant_details_relative_humidity': [53.1, None],
#  '036_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '036_data_instant_details_wind_from_direction': [264.3, None],
#  '036_data_instant_details_wind_speed': [2.9, None],
#  '036_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '036_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '036_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '036_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '036_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '036_data_next_6_hours_details_air_temperature_min': [4.9, None],
#  '036_data_next_6_hours_details_precipitation_amount': [0.0, None],
# ...
#  '037_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '037_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '037_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '037_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '037_data_next_6_hours_details_air_temperature_min': [5.8, None],
#  '037_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '038_time': ['2020-11-02T05:00:00Z', None],
#  '038_data_instant_details_air_pressure_at_sea_level': [1026.7, None],
#  '038_data_instant_details_air_temperature': [5.8, None],
#  '038_data_instant_details_cloud_area_fraction': [0.0, None],
#  '038_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '038_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '038_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '038_data_instant_details_dew_point_temperature': [-6.3, None],
#  '038_data_instant_details_fog_area_fraction': [0.0, None],
#  '038_data_instant_details_relative_humidity': [42.4, None],
#  '038_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '038_data_instant_details_wind_from_direction': [268.9, None],
#  '038_data_instant_details_wind_speed': [4.3, None],
#  '038_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '038_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '038_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '038_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '039_time': ['2020-11-02T06:00:00Z', None],
#  '039_data_instant_details_air_pressure_at_sea_level': [1026.6, None],
#  '039_data_instant_details_air_temperature': [6.1, None],
#  '039_data_instant_details_cloud_area_fraction': [0.0, None],
#  '039_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '039_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '039_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '039_data_instant_details_dew_point_temperature': [-6.5, None],
#  '039_data_instant_details_fog_area_fraction': [0.0, None],
#  '039_data_instant_details_relative_humidity': [40.9, None],
#  '039_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '039_data_instant_details_wind_from_direction': [267.3, None],
#  '039_data_instant_details_wind_speed': [4.1, None],
#  '039_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '039_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '039_data_next_6_hours_details_air_temperature_min': [6.4, None],
#  '039_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '040_time': ['2020-11-02T07:00:00Z', None],
#  '040_data_instant_details_air_pressure_at_sea_level': [1026.3, None],
#  '040_data_instant_details_air_temperature': [6.5, None],
#  '040_data_instant_details_cloud_area_fraction': [0.0, None],
#  '040_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '040_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '040_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '040_data_instant_details_dew_point_temperature': [-7.0, None],
#  '040_data_instant_details_fog_area_fraction': [0.0, None],
#  '040_data_instant_details_relative_humidity': [38.3, None],
#  '040_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '040_data_instant_details_wind_from_direction': [265.5, None],
#  '040_data_instant_details_wind_speed': [4.3, None],
#  '040_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '040_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '040_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '040_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '041_time': ['2020-11-02T08:00:00Z', None],
#  '041_data_instant_details_air_pressure_at_sea_level': [1026.1, None],
#  '041_data_instant_details_air_temperature': [6.8, None],
#  '041_data_instant_details_cloud_area_fraction': [0.0, None],
#  '041_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '041_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '041_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '041_data_instant_details_dew_point_temperature': [-7.4, None],
#  '041_data_instant_details_fog_area_fraction': [0.0, None],
#  '041_data_instant_details_relative_humidity': [36.2, None],
#  '041_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '041_data_instant_details_wind_from_direction': [265.1, None],
#  '041_data_instant_details_wind_speed': [4.5, None],
#  '041_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '041_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '041_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '041_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '041_data_next_6_hours_details_air_temperature_max': [7.1, None],
#  '041_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '041_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '042_time': ['2020-11-02T09:00:00Z', None],
#  '042_data_instant_details_air_pressure_at_sea_level': [1026.0, None],
#  '042_data_instant_details_air_temperature': [7.1, None],
#  '042_data_instant_details_cloud_area_fraction': [0.0, None],
#  '042_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '042_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '042_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '042_data_instant_details_dew_point_temperature': [-7.8, None],
#  '042_data_instant_details_fog_area_fraction': [0.0, None],
#  '042_data_instant_details_relative_humidity': [34.8, None],
#  '042_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '042_data_instant_details_wind_from_direction': [266.3, None],
#  '042_data_instant_details_wind_speed': [4.6, None],
#  '042_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '042_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '042_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '042_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '042_data_next_6_hours_details_air_temperature_max': [9.8, None],
#  '042_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '042_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '043_time': ['2020-11-02T10:00:00Z', None],
#  '043_data_instant_details_air_pressure_at_sea_level': [1025.6, None],
#  '043_data_instant_details_air_temperature': [6.9, None],
#  '043_data_instant_details_cloud_area_fraction': [0.0, None],
#  '043_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '043_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '043_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '043_data_instant_details_dew_point_temperature': [-7.9, None],
#  '043_data_instant_details_fog_area_fraction': [0.0, None],
#  '043_data_instant_details_relative_humidity': [35.0, None],
#  '043_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '043_data_instant_details_wind_from_direction': [269.2, None],
#  '043_data_instant_details_wind_speed': [4.6, None],
#  '043_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '043_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '043_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '043_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '043_data_next_6_hours_details_air_temperature_max': [14.3, None],
#  '043_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '043_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '044_time': ['2020-11-02T11:00:00Z', None],
#  '044_data_instant_details_air_pressure_at_sea_level': [1025.3, None],
#  '044_data_instant_details_air_temperature': [6.5, None],
#  '044_data_instant_details_cloud_area_fraction': [0.0, None],
#  '044_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '044_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '044_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '044_data_instant_details_dew_point_temperature': [-8.0, None],
#  '044_data_instant_details_fog_area_fraction': [0.0, None],
#  '044_data_instant_details_relative_humidity': [35.4, None],
#  '044_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '044_data_instant_details_wind_from_direction': [270.6, None],
#  '044_data_instant_details_wind_speed': [4.6, None],
#  '044_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '044_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '044_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '044_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '044_data_next_6_hours_details_air_temperature_max': [16.6, None],
#  '044_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '044_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '045_time': ['2020-11-02T12:00:00Z', None],
#  '045_data_instant_details_air_pressure_at_sea_level': [1025.4, None],
#  '045_data_instant_details_air_temperature': [6.4, None],
#  '045_data_instant_details_cloud_area_fraction': [0.0, None],
#  '045_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '045_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '045_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '045_data_instant_details_dew_point_temperature': [-8.1, None],
#  '045_data_instant_details_fog_area_fraction': [0.0, None],
#  '045_data_instant_details_relative_humidity': [35.6, None],
#  '045_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '045_data_instant_details_wind_from_direction': [270.0, None],
#  '045_data_instant_details_wind_speed': [4.6, None],
#  '045_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '045_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '045_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '045_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '045_data_next_6_hours_details_air_temperature_max': [17.5, None],
#  '045_data_next_6_hours_details_air_temperature_min': [6.1, None],
#  '045_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '046_time': ['2020-11-02T13:00:00Z', None],
#  '046_data_instant_details_air_pressure_at_sea_level': [1025.3, None],
#  '046_data_instant_details_air_temperature': [6.1, None],
#  '046_data_instant_details_cloud_area_fraction': [0.0, None],
#  '046_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '046_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '046_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '046_data_instant_details_dew_point_temperature': [-8.0, None],
#  '046_data_instant_details_fog_area_fraction': [0.0, None],
#  '046_data_instant_details_relative_humidity': [36.6, None],
#  '046_data_instant_details_ultraviolet_index_clear_sky': [0.0, None],
#  '046_data_instant_details_wind_from_direction': [269.4, None],
#  '046_data_instant_details_wind_speed': [4.4, None],
#  '046_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '046_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '046_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '046_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '046_data_next_6_hours_details_air_temperature_max': [17.8, None],
#  '046_data_next_6_hours_details_air_temperature_min': [6.4, None],
#  '046_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '047_time': ['2020-11-02T14:00:00Z', None],
#  '047_data_instant_details_air_pressure_at_sea_level': [1025.3, None],
#  '047_data_instant_details_air_temperature': [6.4, None],
#  '047_data_instant_details_cloud_area_fraction': [0.0, None],
#  '047_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '047_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '047_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '047_data_instant_details_dew_point_temperature': [-7.3, None],
#  '047_data_instant_details_fog_area_fraction': [0.0, None],
#  '047_data_instant_details_relative_humidity': [37.7, None],
#  '047_data_instant_details_ultraviolet_index_clear_sky': [0.1, None],
#  '047_data_instant_details_wind_from_direction': [270.4, None],
#  '047_data_instant_details_wind_speed': [4.3, None],
#  '047_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '047_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_6_hours_details_air_temperature_max': [18.2, None],
#  '047_data_next_6_hours_details_air_temperature_min': [9.8, None],
#  '047_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '048_time': ['2020-11-02T15:00:00Z', None],
#  '048_data_instant_details_air_pressure_at_sea_level': [1025.7, None],
#  '048_data_instant_details_air_temperature': [9.8, None],
#  '048_data_instant_details_cloud_area_fraction': [0.0, None],
#  '048_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '048_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '048_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '048_data_instant_details_dew_point_temperature': [-4.5, None],
#  '048_data_instant_details_fog_area_fraction': [0.0, None],
#  '048_data_instant_details_relative_humidity': [36.7, None],
#  '048_data_instant_details_ultraviolet_index_clear_sky': [0.7, None],
#  '048_data_instant_details_wind_from_direction': [273.1, None],
#  '048_data_instant_details_wind_speed': [3.8, None],
#  '048_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '048_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_6_hours_details_air_temperature_max': [18.4, None],
#  '048_data_next_6_hours_details_air_temperature_min': [14.3, None],
#  '048_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  '049_time': ['2020-11-02T16:00:00Z', None],
#  '049_data_instant_details_air_pressure_at_sea_level': [1026.0, None],
#  '049_data_instant_details_air_temperature': [14.3, None],
#  '049_data_instant_details_cloud_area_fraction': [0.0, None],
#  '049_data_instant_details_cloud_area_fraction_high': [0.0, None],
#  '049_data_instant_details_cloud_area_fraction_low': [0.0, None],
#  '049_data_instant_details_cloud_area_fraction_medium': [0.0, None],
#  '049_data_instant_details_dew_point_temperature': [-1.8, None],
#  '049_data_instant_details_fog_area_fraction': [0.0, None],
#  '049_data_instant_details_relative_humidity': [33.3, None],
#  '049_data_instant_details_ultraviolet_index_clear_sky': [1.7, None],
#  '049_data_instant_details_wind_from_direction': [285.7, None],
#  '049_data_instant_details_wind_speed': [2.0, None],
#  '049_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_1_hours_details_precipitation_amount': [0.0, None],
#  '049_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_6_hours_details_air_temperature_max': [18.4, None],
#  '049_data_next_6_hours_details_air_temperature_min': [16.6, None],
#  '049_data_next_6_hours_details_precipitation_amount': [0.0, None],
#  ...}

# %%
for k in f_timeseries.keys():
    for meta_k in f_meta.keys():
        if meta_k in k:
            f_timeseries[k][1] = f_meta[meta_k][0]
f_timeseries
# Out:
# {'000_time': ['2020-10-31T15:00:00Z', None],
#  '000_data_instant_details_air_pressure_at_sea_level': [1017.3, 'hPa'],
#  '000_data_instant_details_air_temperature': [6.6, 'celsius'],
#  '000_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '000_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '000_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '000_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '000_data_instant_details_dew_point_temperature': [-3.0, 'celsius'],
#  '000_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '000_data_instant_details_relative_humidity': [51.3, '%'],
#  '000_data_instant_details_ultraviolet_index_clear_sky': [0.8, '1'],
#  '000_data_instant_details_wind_from_direction': [278.4, 'degrees'],
#  '000_data_instant_details_wind_speed': [3.2, 'm/s'],
#  '000_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '000_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '000_data_next_6_hours_details_air_temperature_max': [15.5, 'celsius'],
#  '000_data_next_6_hours_details_air_temperature_min': [11.3, 'celsius'],
#  '000_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '001_time': ['2020-10-31T16:00:00Z', None],
#  '001_data_instant_details_air_pressure_at_sea_level': [1018.1, 'hPa'],
#  '001_data_instant_details_air_temperature': [12.7, 'celsius'],
#  '001_data_instant_details_cloud_area_fraction': [1.6, '%'],
#  '001_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '001_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '001_data_instant_details_cloud_area_fraction_medium': [1.6, '%'],
#  '001_data_instant_details_dew_point_temperature': [-3.5, 'celsius'],
#  '001_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '001_data_instant_details_relative_humidity': [32.7, '%'],
#  '001_data_instant_details_ultraviolet_index_clear_sky': [1.9, '1'],
#  '001_data_instant_details_wind_from_direction': [227.4, 'degrees'],
#  '001_data_instant_details_wind_speed': [1.2, 'm/s'],
#  '001_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '001_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '001_data_next_6_hours_details_air_temperature_max': [15.5, 'celsius'],
#  '001_data_next_6_hours_details_air_temperature_min': [9.9, 'celsius'],
#  '001_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '002_time': ['2020-10-31T17:00:00Z', None],
#  '002_data_instant_details_air_pressure_at_sea_level': [1018.6, 'hPa'],
#  '002_data_instant_details_air_temperature': [13.7, 'celsius'],
#  '002_data_instant_details_cloud_area_fraction': [0.8, '%'],
#  '002_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '002_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '002_data_instant_details_cloud_area_fraction_medium': [0.8, '%'],
#  '002_data_instant_details_dew_point_temperature': [-4.5, 'celsius'],
#  '002_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '002_data_instant_details_relative_humidity': [28.4, '%'],
#  '002_data_instant_details_ultraviolet_index_clear_sky': [3.3, '1'],
#  '002_data_instant_details_wind_from_direction': [84.8, 'degrees'],
#  '002_data_instant_details_wind_speed': [1.8, 'm/s'],
#  '002_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '002_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '002_data_next_6_hours_details_air_temperature_max': [15.5, 'celsius'],
#  '002_data_next_6_hours_details_air_temperature_min': [8.6, 'celsius'],
#  '002_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '003_time': ['2020-10-31T18:00:00Z', None],
#  '003_data_instant_details_air_pressure_at_sea_level': [1019.6, 'hPa'],
#  '003_data_instant_details_air_temperature': [14.7, 'celsius'],
#  '003_data_instant_details_cloud_area_fraction': [0.8, '%'],
#  '003_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '003_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '003_data_instant_details_cloud_area_fraction_medium': [0.8, '%'],
#  '003_data_instant_details_dew_point_temperature': [-4.0, 'celsius'],
#  '003_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '003_data_instant_details_relative_humidity': [27.8, '%'],
#  '003_data_instant_details_ultraviolet_index_clear_sky': [4.2, '1'],
#  '003_data_instant_details_wind_from_direction': [31.5, 'degrees'],
#  '003_data_instant_details_wind_speed': [1.4, 'm/s'],
#  '003_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '003_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '003_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '003_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '003_data_next_6_hours_details_air_temperature_max': [15.5, 'celsius'],
#  '003_data_next_6_hours_details_air_temperature_min': [5.1, 'celsius'],
#  '003_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '004_time': ['2020-10-31T19:00:00Z', None],
#  '004_data_instant_details_air_pressure_at_sea_level': [1020.3, 'hPa'],
#  '004_data_instant_details_air_temperature': [15.5, 'celsius'],
#  '004_data_instant_details_cloud_area_fraction': [0.8, '%'],
#  '004_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '004_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '004_data_instant_details_cloud_area_fraction_medium': [0.8, '%'],
#  '004_data_instant_details_dew_point_temperature': [-4.9, 'celsius'],
#  '004_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '004_data_instant_details_relative_humidity': [24.6, '%'],
#  '004_data_instant_details_ultraviolet_index_clear_sky': [4.2, '1'],
#  '004_data_instant_details_wind_from_direction': [345.9, 'degrees'],
#  '004_data_instant_details_wind_speed': [4.0, 'm/s'],
#  '004_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '004_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '004_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '004_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '004_data_next_6_hours_details_air_temperature_max': [12.2, 'celsius'],
#  '004_data_next_6_hours_details_air_temperature_min': [4.3, 'celsius'],
#  '004_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '005_time': ['2020-10-31T20:00:00Z', None],
#  '005_data_instant_details_air_pressure_at_sea_level': [1022.6, 'hPa'],
#  '005_data_instant_details_air_temperature': [12.2, 'celsius'],
#  '005_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '005_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '005_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '005_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '005_data_instant_details_dew_point_temperature': [-1.9, 'celsius'],
#  '005_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '005_data_instant_details_relative_humidity': [38.1, '%'],
#  '005_data_instant_details_ultraviolet_index_clear_sky': [3.4, '1'],
#  '005_data_instant_details_wind_from_direction': [28.9, 'degrees'],
#  '005_data_instant_details_wind_speed': [5.1, 'm/s'],
#  '005_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '005_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '005_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '005_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '005_data_next_6_hours_details_air_temperature_max': [11.3, 'celsius'],
#  '005_data_next_6_hours_details_air_temperature_min': [3.5, 'celsius'],
#  '005_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '006_time': ['2020-10-31T21:00:00Z', None],
#  '006_data_instant_details_air_pressure_at_sea_level': [1024.1, 'hPa'],
#  '006_data_instant_details_air_temperature': [11.3, 'celsius'],
#  '006_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '006_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '006_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '006_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '006_data_instant_details_dew_point_temperature': [-1.4, 'celsius'],
#  '006_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '006_data_instant_details_relative_humidity': [41.7, '%'],
#  '006_data_instant_details_ultraviolet_index_clear_sky': [2.1, '1'],
#  '006_data_instant_details_wind_from_direction': [41.2, 'degrees'],
#  '006_data_instant_details_wind_speed': [4.2, 'm/s'],
#  '006_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '006_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '006_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '006_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '006_data_next_6_hours_details_air_temperature_max': [9.9, 'celsius'],
#  '006_data_next_6_hours_details_air_temperature_min': [2.8, 'celsius'],
#  '006_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '007_time': ['2020-10-31T22:00:00Z', None],
#  '007_data_instant_details_air_pressure_at_sea_level': [1025.9, 'hPa'],
#  '007_data_instant_details_air_temperature': [9.9, 'celsius'],
#  '007_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '007_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '007_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '007_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '007_data_instant_details_dew_point_temperature': [-1.5, 'celsius'],
#  '007_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '007_data_instant_details_relative_humidity': [45.5, '%'],
#  '007_data_instant_details_ultraviolet_index_clear_sky': [0.9, '1'],
#  '007_data_instant_details_wind_from_direction': [53.3, 'degrees'],
#  '007_data_instant_details_wind_speed': [3.6, 'm/s'],
#  '007_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '007_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '007_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '007_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '007_data_next_6_hours_details_air_temperature_max': [8.6, 'celsius'],
#  '007_data_next_6_hours_details_air_temperature_min': [2.0, 'celsius'],
#  '007_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '008_time': ['2020-10-31T23:00:00Z', None],
#  '008_data_instant_details_air_pressure_at_sea_level': [1027.1, 'hPa'],
#  '008_data_instant_details_air_temperature': [8.6, 'celsius'],
#  '008_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '008_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '008_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '008_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '008_data_instant_details_dew_point_temperature': [-1.7, 'celsius'],
#  '008_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '008_data_instant_details_relative_humidity': [49.0, '%'],
#  '008_data_instant_details_ultraviolet_index_clear_sky': [0.2, '1'],
#  '008_data_instant_details_wind_from_direction': [75.4, 'degrees'],
#  '008_data_instant_details_wind_speed': [1.7, 'm/s'],
#  '008_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '008_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '008_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '008_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '008_data_next_6_hours_details_air_temperature_max': [5.1, 'celsius'],
#  '008_data_next_6_hours_details_air_temperature_min': [0.9, 'celsius'],
#  '008_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '009_time': ['2020-11-01T00:00:00Z', None],
#  '009_data_instant_details_air_pressure_at_sea_level': [1027.9, 'hPa'],
#  '009_data_instant_details_air_temperature': [5.1, 'celsius'],
#  '009_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '009_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '009_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '009_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '009_data_instant_details_dew_point_temperature': [-1.4, 'celsius'],
#  '009_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '009_data_instant_details_relative_humidity': [63.6, '%'],
#  '009_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '009_data_instant_details_wind_from_direction': [215.1, 'degrees'],
#  '009_data_instant_details_wind_speed': [1.4, 'm/s'],
#  '009_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '009_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '009_data_next_6_hours_details_air_temperature_max': [4.3, 'celsius'],
#  '009_data_next_6_hours_details_air_temperature_min': [0.3, 'celsius'],
#  '009_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '010_time': ['2020-11-01T01:00:00Z', None],
#  '010_data_instant_details_air_pressure_at_sea_level': [1028.6, 'hPa'],
#  '010_data_instant_details_air_temperature': [4.3, 'celsius'],
#  '010_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '010_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '010_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '010_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '010_data_instant_details_dew_point_temperature': [-1.6, 'celsius'],
#  '010_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '010_data_instant_details_relative_humidity': [66.7, '%'],
#  '010_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '010_data_instant_details_wind_from_direction': [241.4, 'degrees'],
#  '010_data_instant_details_wind_speed': [1.4, 'm/s'],
#  '010_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '010_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '010_data_next_6_hours_details_air_temperature_max': [3.5, 'celsius'],
#  '010_data_next_6_hours_details_air_temperature_min': [0.2, 'celsius'],
#  '010_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '011_time': ['2020-11-01T02:00:00Z', None],
#  '011_data_instant_details_air_pressure_at_sea_level': [1029.7, 'hPa'],
#  '011_data_instant_details_air_temperature': [3.5, 'celsius'],
#  '011_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '011_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '011_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '011_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '011_data_instant_details_dew_point_temperature': [-1.8, 'celsius'],
#  '011_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '011_data_instant_details_relative_humidity': [69.2, '%'],
#  '011_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '011_data_instant_details_wind_from_direction': [232.1, 'degrees'],
#  '011_data_instant_details_wind_speed': [1.3, 'm/s'],
#  '011_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '011_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '011_data_next_6_hours_details_air_temperature_max': [2.8, 'celsius'],
#  '011_data_next_6_hours_details_air_temperature_min': [0.0, 'celsius'],
#  '011_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '012_time': ['2020-11-01T03:00:00Z', None],
#  '012_data_instant_details_air_pressure_at_sea_level': [1029.9, 'hPa'],
#  '012_data_instant_details_air_temperature': [2.8, 'celsius'],
#  '012_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '012_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '012_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '012_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '012_data_instant_details_dew_point_temperature': [-1.9, 'celsius'],
#  '012_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '012_data_instant_details_relative_humidity': [72.2, '%'],
#  '012_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '012_data_instant_details_wind_from_direction': [235.6, 'degrees'],
#  '012_data_instant_details_wind_speed': [1.5, 'm/s'],
#  '012_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '012_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '012_data_next_6_hours_details_air_temperature_max': [2.0, 'celsius'],
#  '012_data_next_6_hours_details_air_temperature_min': [-0.1, 'celsius'],
#  '012_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '013_time': ['2020-11-01T04:00:00Z', None],
#  '013_data_instant_details_air_pressure_at_sea_level': [1030.2, 'hPa'],
#  '013_data_instant_details_air_temperature': [2.0, 'celsius'],
#  '013_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '013_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '013_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '013_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '013_data_instant_details_dew_point_temperature': [-2.6, 'celsius'],
#  '013_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '013_data_instant_details_relative_humidity': [73.0, '%'],
#  '013_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '013_data_instant_details_wind_from_direction': [233.9, 'degrees'],
#  '013_data_instant_details_wind_speed': [1.6, 'm/s'],
#  '013_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '013_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '013_data_next_6_hours_details_air_temperature_max': [0.9, 'celsius'],
#  '013_data_next_6_hours_details_air_temperature_min': [-0.1, 'celsius'],
#  '013_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '014_time': ['2020-11-01T05:00:00Z', None],
#  '014_data_instant_details_air_pressure_at_sea_level': [1030.5, 'hPa'],
#  '014_data_instant_details_air_temperature': [0.9, 'celsius'],
#  '014_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '014_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '014_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '014_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '014_data_instant_details_dew_point_temperature': [-3.9, 'celsius'],
#  '014_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '014_data_instant_details_relative_humidity': [71.6, '%'],
#  '014_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '014_data_instant_details_wind_from_direction': [253.5, 'degrees'],
#  '014_data_instant_details_wind_speed': [1.8, 'm/s'],
#  '014_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '014_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '014_data_next_6_hours_details_air_temperature_max': [0.6, 'celsius'],
#  '014_data_next_6_hours_details_air_temperature_min': [-0.1, 'celsius'],
#  '014_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '015_time': ['2020-11-01T06:00:00Z', None],
#  '015_data_instant_details_air_pressure_at_sea_level': [1030.3, 'hPa'],
#  '015_data_instant_details_air_temperature': [0.3, 'celsius'],
#  '015_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '015_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '015_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '015_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '015_data_instant_details_dew_point_temperature': [-5.5, 'celsius'],
#  '015_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '015_data_instant_details_relative_humidity': [66.6, '%'],
#  '015_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '015_data_instant_details_wind_from_direction': [262.1, 'degrees'],
#  '015_data_instant_details_wind_speed': [2.0, 'm/s'],
#  '015_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '015_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '015_data_next_6_hours_details_air_temperature_max': [0.6, 'celsius'],
#  '015_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '015_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '016_time': ['2020-11-01T07:00:00Z', None],
#  '016_data_instant_details_air_pressure_at_sea_level': [1029.3, 'hPa'],
#  '016_data_instant_details_air_temperature': [0.2, 'celsius'],
#  '016_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '016_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '016_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '016_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '016_data_instant_details_dew_point_temperature': [-6.7, 'celsius'],
#  '016_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '016_data_instant_details_relative_humidity': [61.0, '%'],
#  '016_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '016_data_instant_details_wind_from_direction': [256.6, 'degrees'],
#  '016_data_instant_details_wind_speed': [2.3, 'm/s'],
#  '016_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '016_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '016_data_next_6_hours_details_air_temperature_max': [0.6, 'celsius'],
#  '016_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '016_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '017_time': ['2020-11-01T08:00:00Z', None],
#  '017_data_instant_details_air_pressure_at_sea_level': [1028.5, 'hPa'],
#  '017_data_instant_details_air_temperature': [0.0, 'celsius'],
#  '017_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '017_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '017_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '017_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '017_data_instant_details_dew_point_temperature': [-7.5, 'celsius'],
#  '017_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '017_data_instant_details_relative_humidity': [58.4, '%'],
#  '017_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '017_data_instant_details_wind_from_direction': [265.4, 'degrees'],
#  '017_data_instant_details_wind_speed': [2.3, 'm/s'],
#  '017_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '017_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '017_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '017_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '017_data_next_6_hours_details_air_temperature_max': [1.0, 'celsius'],
#  '017_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '017_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '018_time': ['2020-11-01T09:00:00Z', None],
#  '018_data_instant_details_air_pressure_at_sea_level': [1028.3, 'hPa'],
#  '018_data_instant_details_air_temperature': [-0.1, 'celsius'],
#  '018_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '018_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '018_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '018_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '018_data_instant_details_dew_point_temperature': [-7.6, 'celsius'],
#  '018_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '018_data_instant_details_relative_humidity': [58.6, '%'],
#  '018_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '018_data_instant_details_wind_from_direction': [273.4, 'degrees'],
#  '018_data_instant_details_wind_speed': [2.9, 'm/s'],
#  '018_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '018_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '018_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '018_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '018_data_next_6_hours_details_air_temperature_max': [5.9, 'celsius'],
#  '018_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '018_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '019_time': ['2020-11-01T10:00:00Z', None],
#  '019_data_instant_details_air_pressure_at_sea_level': [1028.0, 'hPa'],
#  '019_data_instant_details_air_temperature': [0.6, 'celsius'],
#  '019_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '019_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '019_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '019_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '019_data_instant_details_dew_point_temperature': [-7.8, 'celsius'],
#  '019_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '019_data_instant_details_relative_humidity': [54.7, '%'],
#  '019_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '019_data_instant_details_wind_from_direction': [278.7, 'degrees'],
#  '019_data_instant_details_wind_speed': [3.4, 'm/s'],
#  '019_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '019_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '019_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '019_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '019_data_next_6_hours_details_air_temperature_max': [10.5, 'celsius'],
#  '019_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '019_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '020_time': ['2020-11-01T11:00:00Z', None],
#  '020_data_instant_details_air_pressure_at_sea_level': [1028.2, 'hPa'],
#  '020_data_instant_details_air_temperature': [0.4, 'celsius'],
#  '020_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '020_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '020_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '020_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '020_data_instant_details_dew_point_temperature': [-8.4, 'celsius'],
#  '020_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '020_data_instant_details_relative_humidity': [53.1, '%'],
#  '020_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '020_data_instant_details_wind_from_direction': [274.2, 'degrees'],
#  '020_data_instant_details_wind_speed': [2.7, 'm/s'],
#  '020_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '020_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '020_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '020_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '020_data_next_6_hours_details_air_temperature_max': [12.4, 'celsius'],
#  '020_data_next_6_hours_details_air_temperature_min': [-0.2, 'celsius'],
#  '020_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '021_time': ['2020-11-01T12:00:00Z', None],
#  '021_data_instant_details_air_pressure_at_sea_level': [1028.8, 'hPa'],
#  '021_data_instant_details_air_temperature': [-0.2, 'celsius'],
#  '021_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '021_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '021_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '021_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '021_data_instant_details_dew_point_temperature': [-8.9, 'celsius'],
#  '021_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '021_data_instant_details_relative_humidity': [53.4, '%'],
#  '021_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '021_data_instant_details_wind_from_direction': [264.5, 'degrees'],
#  '021_data_instant_details_wind_speed': [2.3, 'm/s'],
#  '021_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '021_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '021_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '021_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '021_data_next_6_hours_details_air_temperature_max': [14.2, 'celsius'],
#  '021_data_next_6_hours_details_air_temperature_min': [-0.1, 'celsius'],
#  '021_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '022_time': ['2020-11-01T13:00:00Z', None],
#  '022_data_instant_details_air_pressure_at_sea_level': [1028.6, 'hPa'],
#  '022_data_instant_details_air_temperature': [-0.1, 'celsius'],
#  '022_data_instant_details_cloud_area_fraction': [0.8, '%'],
#  '022_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '022_data_instant_details_cloud_area_fraction_low': [0.8, '%'],
#  '022_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '022_data_instant_details_dew_point_temperature': [-9.4, 'celsius'],
#  '022_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '022_data_instant_details_relative_humidity': [51.2, '%'],
#  '022_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '022_data_instant_details_wind_from_direction': [263.4, 'degrees'],
#  '022_data_instant_details_wind_speed': [2.6, 'm/s'],
#  '022_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '022_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '022_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '022_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '022_data_next_6_hours_details_air_temperature_max': [15.1, 'celsius'],
#  '022_data_next_6_hours_details_air_temperature_min': [1.0, 'celsius'],
#  '022_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '023_time': ['2020-11-01T14:00:00Z', None],
#  '023_data_instant_details_air_pressure_at_sea_level': [1028.4, 'hPa'],
#  '023_data_instant_details_air_temperature': [1.0, 'celsius'],
#  '023_data_instant_details_cloud_area_fraction': [1.6, '%'],
#  '023_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '023_data_instant_details_cloud_area_fraction_low': [1.6, '%'],
#  '023_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '023_data_instant_details_dew_point_temperature': [-8.8, 'celsius'],
#  '023_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '023_data_instant_details_relative_humidity': [49.5, '%'],
#  '023_data_instant_details_ultraviolet_index_clear_sky': [0.1, '1'],
#  '023_data_instant_details_wind_from_direction': [259.6, 'degrees'],
#  '023_data_instant_details_wind_speed': [2.7, 'm/s'],
#  '023_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '023_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '023_data_next_6_hours_details_air_temperature_max': [15.5, 'celsius'],
#  '023_data_next_6_hours_details_air_temperature_min': [5.9, 'celsius'],
#  '023_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '024_time': ['2020-11-01T15:00:00Z', None],
#  '024_data_instant_details_air_pressure_at_sea_level': [1028.6, 'hPa'],
#  '024_data_instant_details_air_temperature': [5.9, 'celsius'],
#  '024_data_instant_details_cloud_area_fraction': [0.8, '%'],
#  '024_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '024_data_instant_details_cloud_area_fraction_low': [0.8, '%'],
#  '024_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '024_data_instant_details_dew_point_temperature': [-6.1, 'celsius'],
#  '024_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '024_data_instant_details_relative_humidity': [42.9, '%'],
#  '024_data_instant_details_ultraviolet_index_clear_sky': [0.7, '1'],
#  '024_data_instant_details_wind_from_direction': [239.3, 'degrees'],
#  '024_data_instant_details_wind_speed': [2.6, 'm/s'],
#  '024_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '024_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '024_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '024_data_next_6_hours_details_air_temperature_min': [10.5, 'celsius'],
#  '024_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '025_time': ['2020-11-01T16:00:00Z', None],
#  '025_data_instant_details_air_pressure_at_sea_level': [1028.2, 'hPa'],
#  '025_data_instant_details_air_temperature': [10.5, 'celsius'],
#  '025_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '025_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '025_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '025_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '025_data_instant_details_dew_point_temperature': [-4.6, 'celsius'],
#  '025_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '025_data_instant_details_relative_humidity': [34.9, '%'],
#  '025_data_instant_details_ultraviolet_index_clear_sky': [1.9, '1'],
#  '025_data_instant_details_wind_from_direction': [156.3, 'degrees'],
#  '025_data_instant_details_wind_speed': [2.0, 'm/s'],
#  '025_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '025_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '025_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '025_data_next_6_hours_details_air_temperature_min': [12.4, 'celsius'],
#  '025_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '026_time': ['2020-11-01T17:00:00Z', None],
#  '026_data_instant_details_air_pressure_at_sea_level': [1027.9, 'hPa'],
#  '026_data_instant_details_air_temperature': [12.4, 'celsius'],
#  '026_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '026_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '026_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '026_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '026_data_instant_details_dew_point_temperature': [-5.9, 'celsius'],
#  '026_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '026_data_instant_details_relative_humidity': [28.0, '%'],
#  '026_data_instant_details_ultraviolet_index_clear_sky': [3.2, '1'],
#  '026_data_instant_details_wind_from_direction': [138.1, 'degrees'],
#  '026_data_instant_details_wind_speed': [2.1, 'm/s'],
#  '026_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '026_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '026_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '026_data_next_6_hours_details_air_temperature_min': [13.4, 'celsius'],
#  '026_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '027_time': ['2020-11-01T18:00:00Z', None],
#  '027_data_instant_details_air_pressure_at_sea_level': [1027.2, 'hPa'],
#  '027_data_instant_details_air_temperature': [14.2, 'celsius'],
#  '027_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '027_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '027_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '027_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '027_data_instant_details_dew_point_temperature': [-7.3, 'celsius'],
#  '027_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '027_data_instant_details_relative_humidity': [22.5, '%'],
#  '027_data_instant_details_ultraviolet_index_clear_sky': [4.2, '1'],
#  '027_data_instant_details_wind_from_direction': [130.3, 'degrees'],
#  '027_data_instant_details_wind_speed': [1.9, 'm/s'],
#  '027_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '027_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '027_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '027_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '027_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '027_data_next_6_hours_details_air_temperature_min': [11.8, 'celsius'],
#  '027_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '028_time': ['2020-11-01T19:00:00Z', None],
#  '028_data_instant_details_air_pressure_at_sea_level': [1026.4, 'hPa'],
#  '028_data_instant_details_air_temperature': [15.1, 'celsius'],
#  '028_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '028_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '028_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '028_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '028_data_instant_details_dew_point_temperature': [-6.6, 'celsius'],
#  '028_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '028_data_instant_details_relative_humidity': [22.3, '%'],
#  '028_data_instant_details_ultraviolet_index_clear_sky': [4.2, '1'],
#  '028_data_instant_details_wind_from_direction': [113.1, 'degrees'],
#  '028_data_instant_details_wind_speed': [2.1, 'm/s'],
#  '028_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '028_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '028_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '028_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '028_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '028_data_next_6_hours_details_air_temperature_min': [11.2, 'celsius'],
#  '028_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '029_time': ['2020-11-01T20:00:00Z', None],
#  '029_data_instant_details_air_pressure_at_sea_level': [1025.7, 'hPa'],
#  '029_data_instant_details_air_temperature': [15.5, 'celsius'],
#  '029_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '029_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '029_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '029_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '029_data_instant_details_dew_point_temperature': [-5.4, 'celsius'],
#  '029_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '029_data_instant_details_relative_humidity': [23.8, '%'],
#  '029_data_instant_details_ultraviolet_index_clear_sky': [3.5, '1'],
#  '029_data_instant_details_wind_from_direction': [110.5, 'degrees'],
#  '029_data_instant_details_wind_speed': [1.9, 'm/s'],
#  '029_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '029_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '029_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '029_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '029_data_next_6_hours_details_air_temperature_max': [15.7, 'celsius'],
#  '029_data_next_6_hours_details_air_temperature_min': [6.4, 'celsius'],
#  '029_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '030_time': ['2020-11-01T21:00:00Z', None],
#  '030_data_instant_details_air_pressure_at_sea_level': [1025.3, 'hPa'],
#  '030_data_instant_details_air_temperature': [15.7, 'celsius'],
#  '030_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '030_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '030_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '030_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '030_data_instant_details_dew_point_temperature': [-4.5, 'celsius'],
#  '030_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '030_data_instant_details_relative_humidity': [25.1, '%'],
#  '030_data_instant_details_ultraviolet_index_clear_sky': [2.2, '1'],
#  '030_data_instant_details_wind_from_direction': [112.7, 'degrees'],
#  '030_data_instant_details_wind_speed': [1.5, 'm/s'],
#  '030_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '030_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '030_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '030_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '030_data_next_6_hours_details_air_temperature_max': [15.4, 'celsius'],
#  '030_data_next_6_hours_details_air_temperature_min': [5.3, 'celsius'],
#  '030_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '031_time': ['2020-11-01T22:00:00Z', None],
#  '031_data_instant_details_air_pressure_at_sea_level': [1025.4, 'hPa'],
#  '031_data_instant_details_air_temperature': [15.4, 'celsius'],
#  '031_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '031_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '031_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '031_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '031_data_instant_details_dew_point_temperature': [-3.2, 'celsius'],
#  '031_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '031_data_instant_details_relative_humidity': [28.2, '%'],
#  '031_data_instant_details_ultraviolet_index_clear_sky': [0.9, '1'],
#  '031_data_instant_details_wind_from_direction': [113.5, 'degrees'],
#  '031_data_instant_details_wind_speed': [1.4, 'm/s'],
#  '031_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '031_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '031_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '031_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '031_data_next_6_hours_details_air_temperature_max': [13.4, 'celsius'],
#  '031_data_next_6_hours_details_air_temperature_min': [4.9, 'celsius'],
#  '031_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '032_time': ['2020-11-01T23:00:00Z', None],
#  '032_data_instant_details_air_pressure_at_sea_level': [1025.5, 'hPa'],
#  '032_data_instant_details_air_temperature': [13.4, 'celsius'],
#  '032_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '032_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '032_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '032_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '032_data_instant_details_dew_point_temperature': [4.9, 'celsius'],
#  '032_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '032_data_instant_details_relative_humidity': [56.8, '%'],
#  '032_data_instant_details_ultraviolet_index_clear_sky': [0.2, '1'],
#  '032_data_instant_details_wind_from_direction': [109.7, 'degrees'],
#  '032_data_instant_details_wind_speed': [1.1, 'm/s'],
#  '032_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '032_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '032_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '032_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '032_data_next_6_hours_details_air_temperature_max': [11.8, 'celsius'],
#  '032_data_next_6_hours_details_air_temperature_min': [4.9, 'celsius'],
#  '032_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '033_time': ['2020-11-02T00:00:00Z', None],
#  '033_data_instant_details_air_pressure_at_sea_level': [1025.7, 'hPa'],
#  '033_data_instant_details_air_temperature': [11.8, 'celsius'],
#  '033_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '033_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '033_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '033_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '033_data_instant_details_dew_point_temperature': [-1.1, 'celsius'],
#  '033_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '033_data_instant_details_relative_humidity': [41.3, '%'],
#  '033_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '033_data_instant_details_wind_from_direction': [262.6, 'degrees'],
#  '033_data_instant_details_wind_speed': [0.7, 'm/s'],
#  '033_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '033_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '033_data_next_6_hours_details_air_temperature_max': [11.2, 'celsius'],
#  '033_data_next_6_hours_details_air_temperature_min': [4.9, 'celsius'],
#  '033_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '034_time': ['2020-11-02T01:00:00Z', None],
#  '034_data_instant_details_air_pressure_at_sea_level': [1026.4, 'hPa'],
#  '034_data_instant_details_air_temperature': [11.2, 'celsius'],
#  '034_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '034_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '034_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '034_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '034_data_instant_details_dew_point_temperature': [-1.9, 'celsius'],
#  '034_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '034_data_instant_details_relative_humidity': [40.8, '%'],
#  '034_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '034_data_instant_details_wind_from_direction': [263.8, 'degrees'],
#  '034_data_instant_details_wind_speed': [0.3, 'm/s'],
#  '034_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '034_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '034_data_next_6_hours_details_air_temperature_max': [6.5, 'celsius'],
#  '034_data_next_6_hours_details_air_temperature_min': [4.9, 'celsius'],
#  '034_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '035_time': ['2020-11-02T02:00:00Z', None],
#  '035_data_instant_details_air_pressure_at_sea_level': [1027.1, 'hPa'],
#  '035_data_instant_details_air_temperature': [6.4, 'celsius'],
#  '035_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '035_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '035_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '035_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '035_data_instant_details_dew_point_temperature': [-1.9, 'celsius'],
#  '035_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '035_data_instant_details_relative_humidity': [55.8, '%'],
#  '035_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '035_data_instant_details_wind_from_direction': [263.3, 'degrees'],
#  '035_data_instant_details_wind_speed': [1.7, 'm/s'],
#  '035_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '035_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '035_data_next_6_hours_details_air_temperature_max': [6.8, 'celsius'],
#  '035_data_next_6_hours_details_air_temperature_min': [4.9, 'celsius'],
#  '035_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '036_time': ['2020-11-02T03:00:00Z', None],
#  '036_data_instant_details_air_pressure_at_sea_level': [1027.3, 'hPa'],
#  '036_data_instant_details_air_temperature': [5.3, 'celsius'],
#  '036_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '036_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '036_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '036_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '036_data_instant_details_dew_point_temperature': [-3.7, 'celsius'],
#  '036_data_instant_details_fog_area_fraction': [0.0, '%'],
# ...
#  '037_data_next_6_hours_details_air_temperature_min': [5.8, 'celsius'],
#  '037_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '038_time': ['2020-11-02T05:00:00Z', None],
#  '038_data_instant_details_air_pressure_at_sea_level': [1026.7, 'hPa'],
#  '038_data_instant_details_air_temperature': [5.8, 'celsius'],
#  '038_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '038_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '038_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '038_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '038_data_instant_details_dew_point_temperature': [-6.3, 'celsius'],
#  '038_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '038_data_instant_details_relative_humidity': [42.4, '%'],
#  '038_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '038_data_instant_details_wind_from_direction': [268.9, 'degrees'],
#  '038_data_instant_details_wind_speed': [4.3, 'm/s'],
#  '038_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '038_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '038_data_next_6_hours_details_air_temperature_max': [7.1, 'celsius'],
#  '038_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '038_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '039_time': ['2020-11-02T06:00:00Z', None],
#  '039_data_instant_details_air_pressure_at_sea_level': [1026.6, 'hPa'],
#  '039_data_instant_details_air_temperature': [6.1, 'celsius'],
#  '039_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '039_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '039_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '039_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '039_data_instant_details_dew_point_temperature': [-6.5, 'celsius'],
#  '039_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '039_data_instant_details_relative_humidity': [40.9, '%'],
#  '039_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '039_data_instant_details_wind_from_direction': [267.3, 'degrees'],
#  '039_data_instant_details_wind_speed': [4.1, 'm/s'],
#  '039_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '039_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '039_data_next_6_hours_details_air_temperature_max': [7.1, 'celsius'],
#  '039_data_next_6_hours_details_air_temperature_min': [6.4, 'celsius'],
#  '039_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '040_time': ['2020-11-02T07:00:00Z', None],
#  '040_data_instant_details_air_pressure_at_sea_level': [1026.3, 'hPa'],
#  '040_data_instant_details_air_temperature': [6.5, 'celsius'],
#  '040_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '040_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '040_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '040_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '040_data_instant_details_dew_point_temperature': [-7.0, 'celsius'],
#  '040_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '040_data_instant_details_relative_humidity': [38.3, '%'],
#  '040_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '040_data_instant_details_wind_from_direction': [265.5, 'degrees'],
#  '040_data_instant_details_wind_speed': [4.3, 'm/s'],
#  '040_data_next_12_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '040_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '040_data_next_6_hours_details_air_temperature_max': [7.1, 'celsius'],
#  '040_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '040_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '041_time': ['2020-11-02T08:00:00Z', None],
#  '041_data_instant_details_air_pressure_at_sea_level': [1026.1, 'hPa'],
#  '041_data_instant_details_air_temperature': [6.8, 'celsius'],
#  '041_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '041_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '041_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '041_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '041_data_instant_details_dew_point_temperature': [-7.4, 'celsius'],
#  '041_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '041_data_instant_details_relative_humidity': [36.2, '%'],
#  '041_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '041_data_instant_details_wind_from_direction': [265.1, 'degrees'],
#  '041_data_instant_details_wind_speed': [4.5, 'm/s'],
#  '041_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '041_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '041_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '041_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '041_data_next_6_hours_details_air_temperature_max': [7.1, 'celsius'],
#  '041_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '041_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '042_time': ['2020-11-02T09:00:00Z', None],
#  '042_data_instant_details_air_pressure_at_sea_level': [1026.0, 'hPa'],
#  '042_data_instant_details_air_temperature': [7.1, 'celsius'],
#  '042_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '042_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '042_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '042_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '042_data_instant_details_dew_point_temperature': [-7.8, 'celsius'],
#  '042_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '042_data_instant_details_relative_humidity': [34.8, '%'],
#  '042_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '042_data_instant_details_wind_from_direction': [266.3, 'degrees'],
#  '042_data_instant_details_wind_speed': [4.6, 'm/s'],
#  '042_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '042_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '042_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '042_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '042_data_next_6_hours_details_air_temperature_max': [9.8, 'celsius'],
#  '042_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '042_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '043_time': ['2020-11-02T10:00:00Z', None],
#  '043_data_instant_details_air_pressure_at_sea_level': [1025.6, 'hPa'],
#  '043_data_instant_details_air_temperature': [6.9, 'celsius'],
#  '043_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '043_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '043_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '043_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '043_data_instant_details_dew_point_temperature': [-7.9, 'celsius'],
#  '043_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '043_data_instant_details_relative_humidity': [35.0, '%'],
#  '043_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '043_data_instant_details_wind_from_direction': [269.2, 'degrees'],
#  '043_data_instant_details_wind_speed': [4.6, 'm/s'],
#  '043_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '043_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '043_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '043_data_next_6_hours_summary_symbol_code': ['clearsky_night', None],
#  '043_data_next_6_hours_details_air_temperature_max': [14.3, 'celsius'],
#  '043_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '043_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '044_time': ['2020-11-02T11:00:00Z', None],
#  '044_data_instant_details_air_pressure_at_sea_level': [1025.3, 'hPa'],
#  '044_data_instant_details_air_temperature': [6.5, 'celsius'],
#  '044_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '044_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '044_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '044_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '044_data_instant_details_dew_point_temperature': [-8.0, 'celsius'],
#  '044_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '044_data_instant_details_relative_humidity': [35.4, '%'],
#  '044_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '044_data_instant_details_wind_from_direction': [270.6, 'degrees'],
#  '044_data_instant_details_wind_speed': [4.6, 'm/s'],
#  '044_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '044_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '044_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '044_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '044_data_next_6_hours_details_air_temperature_max': [16.6, 'celsius'],
#  '044_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '044_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '045_time': ['2020-11-02T12:00:00Z', None],
#  '045_data_instant_details_air_pressure_at_sea_level': [1025.4, 'hPa'],
#  '045_data_instant_details_air_temperature': [6.4, 'celsius'],
#  '045_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '045_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '045_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '045_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '045_data_instant_details_dew_point_temperature': [-8.1, 'celsius'],
#  '045_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '045_data_instant_details_relative_humidity': [35.6, '%'],
#  '045_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '045_data_instant_details_wind_from_direction': [270.0, 'degrees'],
#  '045_data_instant_details_wind_speed': [4.6, 'm/s'],
#  '045_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '045_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '045_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '045_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '045_data_next_6_hours_details_air_temperature_max': [17.5, 'celsius'],
#  '045_data_next_6_hours_details_air_temperature_min': [6.1, 'celsius'],
#  '045_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '046_time': ['2020-11-02T13:00:00Z', None],
#  '046_data_instant_details_air_pressure_at_sea_level': [1025.3, 'hPa'],
#  '046_data_instant_details_air_temperature': [6.1, 'celsius'],
#  '046_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '046_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '046_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '046_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '046_data_instant_details_dew_point_temperature': [-8.0, 'celsius'],
#  '046_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '046_data_instant_details_relative_humidity': [36.6, '%'],
#  '046_data_instant_details_ultraviolet_index_clear_sky': [0.0, '1'],
#  '046_data_instant_details_wind_from_direction': [269.4, 'degrees'],
#  '046_data_instant_details_wind_speed': [4.4, 'm/s'],
#  '046_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '046_data_next_1_hours_summary_symbol_code': ['clearsky_night', None],
#  '046_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '046_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '046_data_next_6_hours_details_air_temperature_max': [17.8, 'celsius'],
#  '046_data_next_6_hours_details_air_temperature_min': [6.4, 'celsius'],
#  '046_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '047_time': ['2020-11-02T14:00:00Z', None],
#  '047_data_instant_details_air_pressure_at_sea_level': [1025.3, 'hPa'],
#  '047_data_instant_details_air_temperature': [6.4, 'celsius'],
#  '047_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '047_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '047_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '047_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '047_data_instant_details_dew_point_temperature': [-7.3, 'celsius'],
#  '047_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '047_data_instant_details_relative_humidity': [37.7, '%'],
#  '047_data_instant_details_ultraviolet_index_clear_sky': [0.1, '1'],
#  '047_data_instant_details_wind_from_direction': [270.4, 'degrees'],
#  '047_data_instant_details_wind_speed': [4.3, 'm/s'],
#  '047_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '047_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '047_data_next_6_hours_details_air_temperature_max': [18.2, 'celsius'],
#  '047_data_next_6_hours_details_air_temperature_min': [9.8, 'celsius'],
#  '047_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '048_time': ['2020-11-02T15:00:00Z', None],
#  '048_data_instant_details_air_pressure_at_sea_level': [1025.7, 'hPa'],
#  '048_data_instant_details_air_temperature': [9.8, 'celsius'],
#  '048_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '048_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '048_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '048_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '048_data_instant_details_dew_point_temperature': [-4.5, 'celsius'],
#  '048_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '048_data_instant_details_relative_humidity': [36.7, '%'],
#  '048_data_instant_details_ultraviolet_index_clear_sky': [0.7, '1'],
#  '048_data_instant_details_wind_from_direction': [273.1, 'degrees'],
#  '048_data_instant_details_wind_speed': [3.8, 'm/s'],
#  '048_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '048_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '048_data_next_6_hours_details_air_temperature_max': [18.4, 'celsius'],
#  '048_data_next_6_hours_details_air_temperature_min': [14.3, 'celsius'],
#  '048_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  '049_time': ['2020-11-02T16:00:00Z', None],
#  '049_data_instant_details_air_pressure_at_sea_level': [1026.0, 'hPa'],
#  '049_data_instant_details_air_temperature': [14.3, 'celsius'],
#  '049_data_instant_details_cloud_area_fraction': [0.0, '%'],
#  '049_data_instant_details_cloud_area_fraction_high': [0.0, '%'],
#  '049_data_instant_details_cloud_area_fraction_low': [0.0, '%'],
#  '049_data_instant_details_cloud_area_fraction_medium': [0.0, '%'],
#  '049_data_instant_details_dew_point_temperature': [-1.8, 'celsius'],
#  '049_data_instant_details_fog_area_fraction': [0.0, '%'],
#  '049_data_instant_details_relative_humidity': [33.3, '%'],
#  '049_data_instant_details_ultraviolet_index_clear_sky': [1.7, '1'],
#  '049_data_instant_details_wind_from_direction': [285.7, 'degrees'],
#  '049_data_instant_details_wind_speed': [2.0, 'm/s'],
#  '049_data_next_12_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_1_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_1_hours_details_precipitation_amount': [0.0, 'mm'],
#  '049_data_next_6_hours_summary_symbol_code': ['clearsky_day', None],
#  '049_data_next_6_hours_details_air_temperature_max': [18.4, 'celsius'],
#  '049_data_next_6_hours_details_air_temperature_min': [16.6, 'celsius'],
#  '049_data_next_6_hours_details_precipitation_amount': [0.0, 'mm'],
#  ...}

# %%
data = {}
for index, each in enumerate(p):
    data[f'{index:03}_time'] = dictor(each, 'time')
    data[f'{index:03}_symbol_code'] = f'./images/png/{dictor(each, "data.next_1_hours.summary.symbol_code")}.png'
    for datum, value in dictor(each, 'data.instant.details').items():
        data[f'{index:03d}_{datum}'] = value
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-496ab386c1f8> in <module>
#       1 data = {}
# ----> 2 for index, each in enumerate(p):
#       3     data[f'{index:03}_time'] = dictor(each, 'time')
#       4     data[f'{index:03}_symbol_code'] = f'./images/png/{dictor(each, "data.next_1_hours.summary.symbol_code")}.png'
#       5     for datum, value in dictor(each, 'data.instant.details').items():
#
# NameError: name 'p' is not defined

# %%
details = {
'air_pressure_at_sea_level': ('{}_{}', convert),
'air_temperature': ('{}_{}', convert),
'cloud_area_fraction': ('{}_{}', convert),
'cloud_area_fraction_high': ('{}_{}', convert),
'cloud_area_fraction_low': ('{}_{}', convert),
'cloud_area_fraction_medium': ('{}_{}', convert),
'dew_point_temperature': ('{}_{}', convert),
'fog_area_fraction': ('{}_{}', convert),
'relative_humidity': ('{}_{}', convert),
'ultraviolet_index_clear_sky': ('{}_{}', convert),
'wind_from_direction': ('{}_{}', convert),
'wind_speed': ('{}_{}', convert),
}

# %%
def convert(v, u_in, u_out):
    units = {
        'c': { 'c': v , 'f': v*9/5+32, 'k': v + 273.15},
        'f': { 'c': (v-32)*5/9, 'f': v, 'k': (v-32)*5/9 + 273.15},
        'k': { 'c': v-273.15, 'f': (v - 273.15) * 9/5 + 32, 'k': v},
        'm/s': {'m/s': v, 'k/h': v*3.6, 'm/h': v*2.237, 'knt': v*1.944},
        'k/h': {'m/s': v/3.6, 'k/h': v, 'm/h': v/1.609, 'knt': v/1.852},
        'm/h': {'m/s': v/2.237, 'k/h': v*1.609, 'm/h': v, 'knt': v*1.151},
        'knt': {'m/s': v/1.151, 'k/h': v*1.852, 'm/h': v/1.151, 'knt': v}
    }
    try:
        ret_val = units[u_in][u_out]
    except KeyError:
        ret_val = 'undefined'
    return ret_val

# %%
convert(35, 'm/s', 'knt')
# Out:
# 68.03999999999999

# %%
# move into constants
keys = {'time': 'time',
        'details': 'data.instant.details',
        'next_1_hours': 'data.next_1_hours',
        'next_6_hours': 'data.next_6_hours',
        'next_12_hours': 'data.next_12_hours'}

forecast_data = []
for forecast in forecasts_json:
    each_forecast = {}
    for key, dictor_key in keys.items():
        each_forecast[key] = dictor(forecast, dictor_key)
#     each_forecast = {}
#     each_forecast['time'] = dictor(forecast, 'time')
#     each_forecast['data'] = dictor(forecast, 'data.instant.details')
#     each_forecast['next_1_hours'] = dictor(forecast, 'data.next_1_hours')
#     each_forecast['next_6_hours'] = dictor(forecast, 'data.next_6_hours')
#     each_forecast['next_12_hours'] = dictor(forecast, 'data.next_12_hours')
    forecast_data.append(each_forecast)

# %%
from PIL import Image
from pathlib import Path

# %%
for i in g.glob('*.png'):
    img = Image.open(i)
    n_img = Image.new("RGBA", img.size, "WHITE")
    n_img.paste(img, (0, 0), img)
    n_img.save(f'{i.stem}.png')

# %%
json_extract(r.json(), 'next_12_hours')

# %%
from SelfDummy import SelfDummy

# %%
# !ln ../../library/SelfDummy.py ./
